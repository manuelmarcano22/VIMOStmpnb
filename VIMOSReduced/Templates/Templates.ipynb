# %% [markdown]
# # Spectral Classification using templates
#
# In (Jianfeng Wu, Jonker et al 2015) they:
#
#  > present Gemini spectroscopy for 21 candidate optical counterparts to X-ray sources
# discovered in the Galactic Bulge Survey (GBS).
#
# For these sources they classify the spectra using a set of template stars. The set of template stars was chosen from the **library of the Ultraviolet and Visual Echelle Spectrograph Paranal Observatory Project** ([UVES POP](http://www.eso.org/sci/observing/tools/uvespop.html); Jehin et al. 2005), covering spectral types from A0 to M6 with luminosity class of V. The UVES POP template spectra provide coverage over the wavelength range of 3000–10000 Å with a spectral resolution of ∼ 80,000.
#
# > The templates were **re-sampled and Gaussian-smoothed** to match the
# spectral resolution of the object spectra. The object spectra were
# **Doppler-shifted into the same rest frame and averaged**. Each stellar template was optimally subtracted from the object spectrum, while a $\chi^2$ test was performed on the residuals. All the emission lines, DIBs, and telluric features (e.g., Kurucz 2006; Wallace et al. 2011) were masked during the procedure.
#
#
# For example from figure 8 from the article:
#
# ![](images/template.png)
#
#
#
# # This notebook
#
# The purpose of this notebook is to try to recreate what they did to be able to classify spectra for the sources I am working with.
#
# ## A0V HD 162305
#
# In table 4 of (Jianfeng Wu, Jonker et al 2015) they list the templates used. For the spectral type A0V they used **HD 162305** in [NGC 6475](http://simbad.u-strasbg.fr/simbad/sim-id?Ident=HD+162305&NbIdent=1&Radius=10&Radius.unit=arcmin&jsessionid=2D83A5F09A4B709E1A5077131FB78366)
#
# First we import the required packages

# %%
#Import packages
from astropy.io import fits
from astropy.convolution import convolve, Gaussian1DKernel
import os
from stsci.tools import capable
capable.OF_GRAPHICS = False
from pyraf import iraf
import numpy as np
from shutil import copyfile
from astropy.convolution import convolve, Box1DKernel
#Bokeh plotting
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span, Label, Arrow, NormalHead
from bokeh.models import HoverTool, tools, ColumnDataSource, CustomJS, Slider, BoxAnnotation, CheckboxGroup
from bokeh.palettes import viridis, BrBG8, Accent8, OrRd8, Pastel2_4
from bokeh.layouts import row
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6a927ad4-6d63-4caa-84cc-40b2f0e3117c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# After downloading the data for the template star from http://www.eso.org/sci/observing/tools/uvespop/interface.html load the data. The data comes in the format of a fits table. We can look at the header to see what each columns represent and how many rows and columns it has.

# %%
t = fits.open('stars/hd162305.tfits')
data = t[1].data
t[1].header[3:20]
# Out:
# NAXIS1  =                   24 / Characters in a row
# NAXIS2  =               411803 / No. of rows in table
# PCOUNT  =                    0 / Parameter count always 0
# GCOUNT  =                    1 / Group count always 1
# TFIELDS =                    3 / No. of columns in table
#
# TFORM1  = '1D      '           / Format of field
# TDISP1  = 'E15.5   '           / Display format of field
# TTYPE1  = 'Wave    '           / Field label
# TUNIT1  = '        '           / Physical unit of field
# TFORM2  = '1D      '           / Format of field
# TDISP2  = 'E15.5   '           / Display format of field
# TTYPE2  = 'Flux    '           / Field label
# TUNIT2  = '        '           / Physical unit of field
# TFORM3  = '1D      '           / Format of field
# TDISP3  = 'E15.5   '           / Display format of field
# TTYPE3  = 'Sigm    '           / Field label

# %% [markdown]
# From the header above we know that the data has three columns: Wave, Flux and Sigma. Also from the [website](http://www.eso.org/sci/observing/tools/uvespop/legend.html#column3).
#
# > This final file is a tfits table with 3 columns : (1) the wavelengths rebinned to the heliocentric rest frame, (2) the flux of the combined spectra (on an arbitrary scale) and (3) the associated standard deviation.
#
# We get the wave and flux data to plot it. It has 411803 lines to it takes a few seconds and I had to increase the data rate limit of the Jupyter notebook with *--NotebookApp.iopub_data_rate_limit=100000000*. uncomment to run the code and plot the full spectrum.

# %%
waveall = data['Wave']
fluxall = data['Flux']
#source = ColumnDataSource(data=dict(x=waveall,y=fluxall))
#hover = HoverTool(
#        tooltips=[
#            #("index", "$index"),
#            ("(x,y)", "($x{1.11}, $y)"),
#        ]
#    )

#plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra of an A0V: HD 162305",plot_width=900, plot_height=700)
#plot.add_tools(hover)
#plot.add_tools(tools.ResizeTool())
#plot.line('x','y',source=source)
#show(plot)

# %% [markdown]
# # Downsampling by decimation?
#
#
# We see that it takes a while to plot the whole spectra since it has 411803 rows, many more compare to the 2499 row of the data from VIMOS. We can examine the VIMOS data and compare the wavelenght steps and number of elements for both data sets.
#
# ## Sample CX Source: CX59
#
# In each folder we create the spectra for each source. We can recicle the data. For example for CX59 after executing the Notebook for CX59 we select the .txt to plot and compare to the templates. Any changes to the notebook, just execute this cell again to have the updated extracted spectra from the VIMOS source.

# %%
folder = '../cx0059/'
notebook = 'CX59.ipynb'
! jupyter nbconvert --ExecutePreprocessor.timeout=600 \
          --ExecutePreprocessor.kernel_name="python2" --to notebook \
          --execute {folder}{notebook}  --output {folder}{notebook}
! ls {folder}
# Out:
# [NbConvertApp] Converting notebook ../cx0059/CX59.ipynb to notebook
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2291738 bytes to ../cx0059/../cx0059/CX59.ipynb
# CX59.ipynb
# VI_SEXM_575273_2011-05-26T05:19:50.824_G475_MR_202166_Q2_hi.fits
# VI_SRFM_575273_2011-05-26T05:19:50.824_G475_MR_202166_Q2_hi.fits
# VI_SSEM_575273_2011-05-26T05:19:50.824_G475_MR_202166_Q2_hi.fits
# cx59ssem.dispcor.fits
# cx59ssem.fits
# cx59ssem.ms.fits
# cx59ssem.txt
# cx59ssemcont.dispcor.fits
# cx59ssemcont.fits
# cx59ssemcont.txt
# database
# images
# logfile
# login.cl
# pyraf
# uparm

# %% [markdown]
# We select the **.txt** we want to examine the VIMOS data and compare the wavelenght steps and number of elements for both data sets.

# %%
#Sample data
sourcename = folder+'cx59ssem.txt'
xspectra=[]
yspectra=[]
with open(sourcename) as f:
    for lines in f:
        xspectra.append(float(lines.split()[0]))
        yspectra.append(float(lines.split()[1]))

xspectra = np.array(xspectra)
print('VIMOS data steps: min {} max {}'.format(np.diff(xspectra).min(), np.diff(xspectra).max()))
print('Template data steps: min {} max {}'.format(np.diff(waveall).min(), np.diff(waveall).max()))
print('Rows VIMOS data: '+str(len(xspectra)))
# Out:
# VIMOS data steps: min 2.6 max 2.6
# Template data steps: min 0.0124886001017 max 0.0516544209804
# Rows VIMOS data: 2499

# %% [markdown]
# We can notice that the steps for the template are much shorter and also seem to be uneven. One first try to be able to compare both dataset is to only take from the templates those wavelenghts and fluxes closer to the VIMOS data.

# %%
equalwaves = []
equalflux = []
for i in xspectra:
    indx = np.where(abs(waveall-i) < 0.1)
    equalwaves.append(waveall[indx][0])
    equalflux.append(fluxall[indx][0])
print('VIMOS data steps: min {} max {}'.format(np.diff(xspectra).min(), np.diff(xspectra).max()))
print('New Template data steps: min {} max {}'.format(np.diff(equalwaves).min(), np.diff(equalwaves).max()))
print('Rows New VIMOS data: '+str(len(equalwaves)))
print('Maximum separation: {}'.format(abs(equalwaves -xspectra).max()))
# Out:
# VIMOS data steps: min 2.6 max 2.6
# New Template data steps: min 2.58272104898 max 2.61970865371
# Rows New VIMOS data: 2499
# Maximum separation: 0.0999976922049

# %% [markdown]
# Now it is more equally distributed around 2. 6. It is still not totally uniform step, but now it has the same number of elements as the VIMOS data. The largest difference in wavelenght between both data set is of 0.099. We can plot it.

# %%
source = ColumnDataSource(data=dict(x=equalwaves,y=equalflux))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra of an A0V: HD 162305",plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2121ce4e-d658-4ad6-bb9b-4d57d0013f29"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2121ce4e-d658-4ad6-bb9b-4d57d0013f29");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2121ce4e-d658-4ad6-bb9b-4d57d0013f29");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2121ce4e-d658-4ad6-bb9b-4d57d0013f29' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"651989e0-fa8b-4def-b0c8-1f4e30994fb6":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"6a1f65a5-87cf-4aac-904b-4ffed9fb455b","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4547871-b179-4deb-a9bc-ee2dffa0f01b","type":"BasicTicker"}},"id":"d689e717-ecd8-46af-a31a-7152e9a8aabb","type":"Grid"},{"attributes":{},"id":"4d60ab4f-a949-4a5e-a106-adb758276616","type":"LinearScale"},{"attributes":{"plot":{"id":"6a1f65a5-87cf-4aac-904b-4ffed9fb455b","subtype":"Figure","type":"Plot"}},"id":"8e91374d-738b-44d0-afa2-086965c4dc44","type":"SaveTool"},{"attributes":{"plot":{"id":"6a1f65a5-87cf-4aac-904b-4ffed9fb455b","subtype":"Figure","type":"Plot"}},"id":"0097f9de-4781-4c9c-a083-4ae3601e270b","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6a1f65a5-87cf-4aac-904b-4ffed9fb455b","subtype":"Figure","type":"Plot"},"ticker":{"id":"4027644d-2744-40bd-a8cd-005caf6b3eef","type":"BasicTicker"}},"id":"082af3c4-6711-4cff-a848-a7a2ce49b07a","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7def38fc-e7d6-4d17-81ae-d67f2aee3050","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"96dfd5fe-efd4-4a37-b961-71439cab50ba","type":"Line"},{"attributes":{},"id":"000f66ff-8f59-465e-9295-70c5167528bd","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fa817aff-a955-482b-95cc-3f0da6a1b108","type":"Line"},{"attributes":{"axis_label":"Y","formatter":{"id":"3a1b5c57-d90f-4577-aaa6-86aef2eaf9ea","type":"BasicTickFormatter"},"plot":{"id":"6a1f65a5-87cf-4aac-904b-4ffed9fb455b","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4547871-b179-4deb-a9bc-ee2dffa0f01b","type":"BasicTicker"}},"id":"36366510-a68b-4f24-89eb-8a6df57aea10","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Spectra of an A0V: HD 162305"},"id":"535d34fb-7f30-4662-a57d-36de98b574c3","type":"Title"},{"attributes":{"plot":{"id":"6a1f65a5-87cf-4aac-904b-4ffed9fb455b","subtype":"Figure","type":"Plot"}},"id":"2e1892b9-3c68-4ac1-b46d-643dc82e9ac1","type":"ResetTool"},{"attributes":{},"id":"3a1b5c57-d90f-4577-aaa6-86aef2eaf9ea","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3501.2116985554912,3503.809327376718,3506.406956197945,3509.0045850191714,3511.6022138403982,3514.2123312617273,3516.8099600829537,3519.4075889041806,3522.0052177254074,3524.6028465466343,3527.2004753678607,3529.8105927891897,3532.4082216104166,3535.005850431643,3537.60347925287,3540.2011080740967,3542.8112254954253,3545.408854316652,3548.006483137879,3550.604111959106,3553.2017407803323,3555.8118582016614,3558.4094870228882,3561.0071158441147,3563.6047446653415,3566.2023734865684,3568.8000023077952,3571.410119729124,3574.0077485503507,3576.6053773715776,3579.203006192804,3581.800635014031,3584.41075243536,3587.0083812565863,3589.606010077813,3592.20363889904,3594.801267720267,3597.4113851415955,3600.0090139628223,3602.606642784049,3605.2042716052756,3607.8019004265025,3610.4120178478315,3613.009646669058,3615.607275490285,3618.2049043115117,3620.8025331327385,3623.400161953965,3626.010279375294,3628.607908196521,3631.2055370177472,3633.803165838974,3636.400794660201,3639.0109120815296,3641.6085409027564,3644.2061697239833,3646.80379854521,3649.4014273664366,3652.0115447877656,3654.6091736089925,3657.206802430219,3659.8044312514457,3662.4020600726726,3665.012177494001,3667.609806315228,3670.207435136455,3672.805063957682,3675.402692778908,3678.000321600135,3680.610439021464,3683.2080678426905,3685.8056966639174,3688.4033254851443,3691.000954306371,3693.6110717276997,3696.2087005489266,3698. ...

# %% [markdown]
# # Gaussian-smoothing
#
# One of the steps mentioned in the paper was to do a gaussian smooth. This can be done in several ways with python. One using scipy package and the routine [scipy.ndimage.filters.gaussian_filter](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.ndimage.filters.gaussian_filter.html) or [Astropy.convolution](http://docs.astropy.org/en/stable/convolution/).
#
# The Gaussian1Dkernel takes as required argument the standard deviation of the Gaussian kernel.
#
# We can try to do a smoothing of the recently selected wavelenght data from the template

# %%
# Do the smoothing
fluxgaussian10 = convolve(equalflux, Gaussian1DKernel(stddev=2))
#Plot
source = ColumnDataSource(data=dict(x=equalwaves,y=fluxgaussian10))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Smoothed Spectra",plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c178b2a-9355-4ea3-9dde-63c6e82c80d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8c178b2a-9355-4ea3-9dde-63c6e82c80d5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c178b2a-9355-4ea3-9dde-63c6e82c80d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c178b2a-9355-4ea3-9dde-63c6e82c80d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"59cd748a-d66a-47e1-8013-c46633a30a40":{"roots":{"references":[{"attributes":{"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"}},"id":"90958b90-c791-4ebf-828e-28e2155572c0","type":"HelpTool"},{"attributes":{},"id":"cb9cefd8-3c34-49bb-948b-eab2a713643c","type":"BasicTicker"},{"attributes":{"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"}},"id":"5fb4c41c-e141-4007-bae9-cf131c616152","type":"ResizeTool"},{"attributes":{"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"04902fc7-d4be-4b7a-b37f-cfa712134b58","type":"BasicTicker"}},"id":"cc6f8f4b-c023-4169-be70-c23386616356","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d0b865f-042d-44db-83e0-fc6baf3581dc","type":"Line"},{"attributes":{"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"}},"id":"413d3dfa-cd24-4be1-9dd4-7ee862fb7e99","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"d5f52654-2aee-4915-8ba1-cda323db67ea","type":"LinearAxis"}],"left":[{"id":"61c01748-275e-4eb7-bd7b-63dd039117b0","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"d5f52654-2aee-4915-8ba1-cda323db67ea","type":"LinearAxis"},{"id":"cc6f8f4b-c023-4169-be70-c23386616356","type":"Grid"},{"id":"61c01748-275e-4eb7-bd7b-63dd039117b0","type":"LinearAxis"},{"id":"d994aa38-ffc7-4c87-b80b-f6fc8bccc04e","type":"Grid"},{"id":"74e9480b-1bd7-4da3-8d37-c59467dc3c82","type":"BoxAnnotation"},{"id":"241adaec-0a77-4b8f-b65a-ffaca772bd89","type":"GlyphRenderer"}],"title":{"id":"f0e3d785-0cf7-417d-af5c-842917f9c50e","type":"Title"},"tool_events":{"id":"64d87127-e1e3-44c8-963e-c82d2fee38a5","type":"ToolEvents"},"toolbar":{"id":"3090272b-4dd6-427f-a8b4-870407f4dd64","type":"Toolbar"},"x_range":{"id":"5bd09704-4b14-41dc-8983-95de21416221","type":"DataRange1d"},"x_scale":{"id":"550f27f4-fe54-4c9a-bbbf-a8a7cfe75ed3","type":"LinearScale"},"y_range":{"id":"04054132-1338-42d2-b33e-e77c4d282a66","type":"DataRange1d"},"y_scale":{"id":"8c27f70a-10f0-496f-a811-573e73e9cd7e","type":"LinearScale"}},"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Smoothed Spectra"},"id":"f0e3d785-0cf7-417d-af5c-842917f9c50e","type":"Title"},{"attributes":{},"id":"550f27f4-fe54-4c9a-bbbf-a8a7cfe75ed3","type":"LinearScale"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"2f8a4113-ae88-4aa2-a70b-2cac86bd1e89","type":"BasicTickFormatter"},"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"04902fc7-d4be-4b7a-b37f-cfa712134b58","type":"BasicTicker"}},"id":"d5f52654-2aee-4915-8ba1-cda323db67ea","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"},"tooltips":[["(x,y)","($x{1.11}, $y)"]]},"id":"1c7629ea-0f60-48ca-b515-7b384d5bd5c9","type":"HoverTool"},{"attributes":{},"id":"8c27f70a-10f0-496f-a811-573e73e9cd7e","type":"LinearScale"},{"attributes":{"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","subtype":"Figure","type":"Plot"}},"id":"173f7efe-67ca-41d4-8efa-6eb963b53f2d","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"74e9480b-1bd7-4da3-8d37-c59467dc3c82","type":"BoxAnnotation"},{"attributes":{},"id":"0b1e4fd3-b83d-4d6b-b9e0-4fcf401eeb98","type":"BasicTickFormatter"},{"attributes":{},"id":"64d87127-e1e3-44c8-963e-c82d2fee38a5","type":"ToolEvents"},{"attributes":{"overlay":{"id":"74e9480b-1bd7-4da3-8d37-c59467dc3c82","type":"BoxAnnotation"},"plot":{"id":"dd26cba4-d886-4e84-8dbc-5a5ced8d0e7d","su ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We need to normalize both spectra to compare them.
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght. For the CX source we use the spectra created in [Notebook CX59](../cx0059/CX59.ipynb)

# %% [markdown]
# ### For the CX source
#
# In each folder we create the spectra for each source. We can recicle the data. For example for CX59 after executing the Notebook for CX59 we select the .txt to plot and compare to the templates. Any changes to the notebook, just execute this cell again to have the updated extracted spectra from the VIMOS source.

# %%
folder = '../cx0059/'
notebook = 'CX59.ipynb'
! jupyter nbconvert --ExecutePreprocessor.timeout=600 \
          --ExecutePreprocessor.kernel_name="python2" --to notebook \
          --execute {folder}{notebook}  --output {folder}{notebook}
! ls {folder}
# Out:
# [NbConvertApp] Converting notebook ../cx0059/CX59.ipynb to notebook
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2291738 bytes to ../cx0059/../cx0059/CX59.ipynb
# CX59.ipynb
# VI_SEXM_575273_2011-05-26T05:19:50.824_G475_MR_202166_Q2_hi.fits
# VI_SRFM_575273_2011-05-26T05:19:50.824_G475_MR_202166_Q2_hi.fits
# VI_SSEM_575273_2011-05-26T05:19:50.824_G475_MR_202166_Q2_hi.fits
# cx59ssem.dispcor.fits
# cx59ssem.fits
# cx59ssem.ms.fits
# cx59ssem.txt
# cx59ssemcont.dispcor.fits
# cx59ssemcont.fits
# cx59ssemcont.txt
# database
# images
# logfile
# login.cl
# pyraf
# uparm

# %% [markdown]
# We select the **.txt** we want to use.

# %%
sourcename = folder+'cx59ssemcont.txt'
#Plotting
xr = (7700,8900)
yr = (0.5,1.4)

xcx=[]
ycx=[]

with open(sourcename) as f:
    for lines in f:
        xcx.append(float(lines.split()[0]))
        ycx.append(float(lines.split()[1]))

#toxcx = np.array(xcx)
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=xcx,y=ycx))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a89a2c8f-277a-4d2e-bf92-14551ca1b6b3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a89a2c8f-277a-4d2e-bf92-14551ca1b6b3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a89a2c8f-277a-4d2e-bf92-14551ca1b6b3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a89a2c8f-277a-4d2e-bf92-14551ca1b6b3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eca4a072-ecef-4b45-9eb5-d696823590d4":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"},"tooltips":[["(x,y)","($x{1.11}, $y)"]]},"id":"8eb97ff7-8d5b-43fe-9737-f38eb9b8aac4","type":"HoverTool"},{"attributes":{"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"}},"id":"27c7a754-a436-4782-944a-ee5d3dd79ac7","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"}},"id":"30a6d671-a1eb-49e7-bf61-85c537f3ad34","type":"HelpTool"},{"attributes":{},"id":"0290a5ab-9c65-45b5-b282-4be815d00007","type":"BasicTicker"},{"attributes":{},"id":"c756a89c-1994-40f8-aae0-08abd80a5845","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"}},"id":"b4f232dd-217a-4e99-9101-c7e3fbc23ef7","type":"ResizeTool"},{"attributes":{"dimension":1,"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"},"ticker":{"id":"0290a5ab-9c65-45b5-b282-4be815d00007","type":"BasicTicker"}},"id":"3047024c-09a0-4567-a35e-36a163d4a7ab","type":"Grid"},{"attributes":{"overlay":{"id":"96bd2a58-02d2-4de6-b3c2-550b5408fa63","type":"BoxAnnotation"},"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"}},"id":"f4876314-b640-42a3-bd3c-37e6bb7a6de7","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"96bd2a58-02d2-4de6-b3c2-550b5408fa63","type":"BoxAnnotation"},{"attributes":{},"id":"43ea167c-b420-4f83-bb28-3c9df4887268","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":1.4,"start":0.5},"id":"9dd41b8e-d4ee-4b36-8184-5d855e3877d0","type":"Range1d"},{"attributes":{"callback":null,"end":8900,"start":7700},"id":"81e906fd-b453-4eb3-a364-29f22fab0976","type":"Range1d"},{"attributes":{"data_source":{"id":"865597c3-3577-4a57-9ccf-03fae1ec4509","type":"ColumnDataSource"},"glyph":{"id":"dfcfeff5-f5c5-4930-8595-b5a150bf1a8a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7d74408b-9fe5-48e9-b0fa-4319d05400cc","type":"Line"},"selection_glyph":null},"id":"10223712-7b4a-4bcb-b88c-0196787ca9e1","type":"GlyphRenderer"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"c756a89c-1994-40f8-aae0-08abd80a5845","type":"BasicTickFormatter"},"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"},"ticker":{"id":"988af5f1-e188-4f15-aa77-27875abffaee","type":"BasicTicker"}},"id":"b4bcbced-9a96-4aa0-918e-846813e1749e","type":"LinearAxis"},{"attributes":{},"id":"aee99f8b-1334-44ea-9441-33343555e57c","type":"LinearScale"},{"attributes":{"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"},"ticker":{"id":"988af5f1-e188-4f15-aa77-27875abffaee","type":"BasicTicker"}},"id":"4e212504-41ac-4174-a6e6-a3069fa6d57d","type":"Grid"},{"attributes":{},"id":"988af5f1-e188-4f15-aa77-27875abffaee","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d74408b-9fe5-48e9-b0fa-4319d05400cc","type":"Line"},{"attributes":{"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"}},"id":"67da3c88-fbd7-4fd4-9c5c-403fa472b9b0","type":"PanTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dfcfeff5-f5c5-4930-8595-b5a150bf1a8a","type":"Line"},{"attributes":{"plot":{"id":"f2f7f35b-8ed5-47b9-999c-b08ca9791f80","subtype":"Figure","type":"Plot"}},"id":"ca8d2273-a0c1-4873-8fa1-15f08bd744a1","type":"ResetTool"},{"attributes":{"plot" ...

# %% [markdown]
# ## For the Smooth and decimated template
#
# From the data need to create a fits image to apply continuum iraf routine to it. One way to do this is show below. There are probably better ways. I am assuming that the step separtion is 2.6 so has the same wavelength axis than the VIMOS data. Lets look at the header of the VIMOS data

# %%
cx = fits.open('../cx0059/cx59ssem.ms.fits')
cx[0].header[0:34]
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    3 / Number of axes
# NAXIS1  =                 2499 / Axis length
# NAXIS2  =                    1 / Axis length
# NAXIS3  =                    4 / Axis length
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '2017-06-29T22:19:15' / Time of last modification
# OBJECT  = '453432_GBS'         / Name of the object observed
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2017-06-29T22:19:15' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# MJD-OBS =       55707.22211602 / Obs start 2011-05-26T05:19:50.824
# DATE-OBS= '2011-05-26T05:19:50.824' / Date of observation
# EXPTIME =              875.001 / Total integration time. 00:14:35.001
# TELESCOP= 'ESO-VLT-U3'         / ESO <TEL>
# RA      =           266.213591 / 17:44:51.2 RA (J2000) pointing
# DEC     =            -26.32936 / -26:19:45.6  DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# LST     =            60714.444 / 16:51:54.444 LST at start
# UTC     =               19186. / 05:19:46.000 UT at start
# OBSERVER= 'VIMOS   '           / Name of observer
# INSTRUME= 'VIMOS   '           / Instrument used
# PI-COI  = '555555555'          / Name of PI and COI
# CRVAL1  =               3501.3 / 17:44:51.2, RA at ref pixel
# CRPIX1  =                   1. / Reference pixel in X
# CTYPE1  = 'PIXEL   '           / pixel coordinate system
# CTYPE2  = 'LINEAR  '           / pixel coordinate system
# CD1_1   =                  2.6 / Translation matrix element
# CD2_2   =                   1. / Translation matrix element
# CHECKSUM= '9VheATgZ3Tgd9TgZ'   / HDU checksum updated 2011-06-09T17:55:41
# DATASUM = '2210294345'         / data unit checksum updated 2011-05-30T08:48:44

# %% [markdown]
# The relevant header information are NAXIS#, CRVAl#, CTYPE, CD#_#. We copy this to the header of the new fits woth the smoothed template data we can create.

# %%
name = 'fluxsmooth'
if os.path.exists(name+'.fits'):
    os.remove(name+'.fits')
hdu = fits.PrimaryHDU(fluxgaussian10)
hdu.writeto(name+'.fits')
data, header = fits.getdata(name+'.fits', header=True)
header['NAXIS'] = 2
header['NAXIS2'] = 2499
header['CRVAL1'] = 3501.3
header['CRPIX1'] = 1.
header['CTYPE1'] = 'PIXEL'
header['CTYPE2'] = 'LINEAR'
header['CD1_1'] = 2.6
header['CD2_2'] = 1.
header
fits.writeto(name+'.fits', data, header, overwrite=True)

# %% [markdown]
# ### Smoothed template Continuum
#
# Now we can normalize using iraf continuum.

# %%
sourcename = name
sample = '*'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

#Plotting
#Plotting
xr = (5000,8900)
yr = (0.5,1.4)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# fluxsmoothcont.fits: Resampling using current coordinate system
# fluxsmoothcont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0a838469-e096-4b31-a192-555b4927c1dc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0a838469-e096-4b31-a192-555b4927c1dc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a838469-e096-4b31-a192-555b4927c1dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a838469-e096-4b31-a192-555b4927c1dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca564780-b2cc-44da-825c-fa6f999156b0":{"roots":{"references":[{"attributes":{},"id":"d8e22602-b1d8-4cfd-8a18-ae631128aab5","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"85f99b96-5402-4385-a9ce-ea58f805b1be","type":"ColumnDataSource"},"glyph":{"id":"7e45087b-4633-443d-b56a-eb2801b46f19","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ec8ddfce-d9ca-4d26-8d41-8c1bcb5ca749","type":"Line"},"selection_glyph":null},"id":"9aa198ae-3bbc-4f66-aa6f-7999b954386d","type":"GlyphRenderer"},{"attributes":{"axis_label":"Y","formatter":{"id":"580c0bcc-4f1b-4dd4-b694-896ee50af04f","type":"BasicTickFormatter"},"plot":{"id":"32d76d58-e154-4208-9611-7e580a3c8752","subtype":"Figure","type":"Plot"},"ticker":{"id":"6855d465-e9c5-4561-88f8-b0096fc703ba","type":"BasicTicker"}},"id":"f532792c-e2a6-4a6c-907a-2c501fdb7966","type":"LinearAxis"},{"attributes":{"plot":{"id":"32d76d58-e154-4208-9611-7e580a3c8752","subtype":"Figure","type":"Plot"},"ticker":{"id":"97755d7d-8eb0-495b-8465-a5bf90261059","type":"BasicTicker"}},"id":"960b212d-2f5e-4e77-ae47-1749f0ae5472","type":"Grid"},{"attributes":{"below":[{"id":"6874d32f-5ea1-49a5-a41b-5a043270986b","type":"LinearAxis"}],"left":[{"id":"f532792c-e2a6-4a6c-907a-2c501fdb7966","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"6874d32f-5ea1-49a5-a41b-5a043270986b","type":"LinearAxis"},{"id":"960b212d-2f5e-4e77-ae47-1749f0ae5472","type":"Grid"},{"id":"f532792c-e2a6-4a6c-907a-2c501fdb7966","type":"LinearAxis"},{"id":"8f18984a-753e-4917-a4ed-5de17ab555b6","type":"Grid"},{"id":"5114bd37-4d0a-4bb8-94c3-049430278ac5","type":"BoxAnnotation"},{"id":"9aa198ae-3bbc-4f66-aa6f-7999b954386d","type":"GlyphRenderer"}],"title":{"id":"b1c66ee7-3406-456a-8fbb-bb8ff59829a5","type":"Title"},"tool_events":{"id":"a1ee8ead-3e9a-47b0-95ae-1a305dcce968","type":"ToolEvents"},"toolbar":{"id":"e3a6a00c-8983-469b-9ef6-08d4b736571e","type":"Toolbar"},"x_range":{"id":"b05114ed-da9a-4aaf-8321-26018f55889d","type":"Range1d"},"x_scale":{"id":"4f20d456-dd7a-4e6b-bc47-cfac74c37dd1","type":"LinearScale"},"y_range":{"id":"b410afb7-bafa-4322-9d2a-eaa4b7a5c0c3","type":"Range1d"},"y_scale":{"id":"0512b556-4456-4512-913b-18ca5bc6fa85","type":"LinearScale"}},"id":"32d76d58-e154-4208-9611-7e580a3c8752","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7e45087b-4633-443d-b56a-eb2801b46f19","type":"Line"},{"attributes":{},"id":"6855d465-e9c5-4561-88f8-b0096fc703ba","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ec8ddfce-d9ca-4d26-8d41-8c1bcb5ca749","type":"Line"},{"attributes":{"plot":null,"text":"Spectra"},"id":"b1c66ee7-3406-456a-8fbb-bb8ff59829a5","type":"Title"},{"attributes":{"plot":{"id":"32d76d58-e154-4208-9611-7e580a3c8752","subtype":"Figure","type":"Plot"}},"id":"804a5de7-7e7c-4c2e-befd-b157d12e696e","type":"ResizeTool"},{"attributes":{},"id":"4f20d456-dd7a-4e6b-bc47-cfac74c37dd1","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5114bd37-4d0a-4bb8-94c3-049430278ac5","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"5114bd37-4d0a-4bb8-94c3-049430278ac5","type":"BoxAnnotation"},"plot":{"id":"32d76d58-e154-4208-9611-7e580a3c8752","subtype":"Figure","type":"Plot"}},"id":"fde82964-5f40-427a-9ae1-6121d8a655ca","type":"BoxZoomTool"},{"attributes":{},"id":"97755d7d-8eb0-495b-8465-a5bf90261059","type":"BasicTicker"},{"attributes":{"plot":{"id":"32d76d58-e154-4208-9611-7e580a3c8752","subtype":"Figure","type":"Plot"}},"id":"cd696d6a-933d-44e6-8bf7-c76beecbd716","type":"ResetTool"},{"attributes" ...

# %% [markdown]
# # Together
#  We can plot both graphs after being normalized

# %%
xr = (7700,8900)
yr = (0.5,1.4)
p =  figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
r = p.line(x=x, y=y,color='firebrick',line_width=4,line_alpha=0.8,legend='CX Source')
p.line(x=xcx,y=ycx,color='navy', line_alpha=0.3, line_width=4,legend='Template',muted_alpha=0.1)
p.legend.location = "top_left"
p.legend.click_policy="mute"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="18175310-ead5-4eb8-8e73-e330434144aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("18175310-ead5-4eb8-8e73-e330434144aa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("18175310-ead5-4eb8-8e73-e330434144aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '18175310-ead5-4eb8-8e73-e330434144aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32f95022-8215-453e-bee4-8139ee1b3509":{"roots":{"references":[{"attributes":{"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc682325-a7bf-4d19-b261-792115ad3d58","type":"BasicTicker"}},"id":"7618e967-59f3-4f86-a61e-d9f4e0f50250","type":"Grid"},{"attributes":{"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"}},"id":"645e8c3c-a3bf-4bbb-8ee1-f9b16d6a67d5","type":"HelpTool"},{"attributes":{"callback":null,"end":8900,"start":7700},"id":"8b2866e0-d08b-4ddc-a41e-a652f236117b","type":"Range1d"},{"attributes":{"axis_label":"Y","formatter":{"id":"44d56b71-b43b-4089-8d79-392e80e0c46f","type":"BasicTickFormatter"},"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1cc5810-5b86-4672-8229-72f3e7f71033","type":"BasicTicker"}},"id":"cd6a8f0e-c34d-4237-9744-31dcf56599ee","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"024884b7-60d1-424c-ad53-bdc8f365a038","type":"Line"},{"attributes":{},"id":"fc682325-a7bf-4d19-b261-792115ad3d58","type":"BasicTicker"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"72782e0d-f64f-45d6-b4d9-2b13d6e7881a","type":"BasicTickFormatter"},"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc682325-a7bf-4d19-b261-792115ad3d58","type":"BasicTicker"}},"id":"d607a788-a781-457d-a3f0-05ddb66867ef","type":"LinearAxis"},{"attributes":{"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"}},"id":"15268693-0e3a-48b2-975f-b0ea9dc09e23","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1cc5810-5b86-4672-8229-72f3e7f71033","type":"BasicTicker"}},"id":"484c00b1-6674-4c72-ab60-d0e98986422d","type":"Grid"},{"attributes":{"data_source":{"id":"410d2f1a-ce5a-435b-a78f-126fe9303897","type":"ColumnDataSource"},"glyph":{"id":"f0f01f3a-2cce-48ad-b5c9-ec1636ae050f","type":"Line"},"hover_glyph":null,"muted_glyph":{"id":"fed48ad8-b745-4caf-b10a-f20bdeccad49","type":"Line"},"nonselection_glyph":{"id":"024884b7-60d1-424c-ad53-bdc8f365a038","type":"Line"},"selection_glyph":null},"id":"e0710d4a-4977-434d-8157-843274ca616d","type":"GlyphRenderer"},{"attributes":{},"id":"5fdca6fc-b73e-41ca-900e-fba4726c7659","type":"LinearScale"},{"attributes":{"callback":null,"end":1.4,"start":0.5},"id":"cbd70d73-e895-44e2-8bbc-ac2eafc3f639","type":"Range1d"},{"attributes":{"label":{"value":"Template"},"renderers":[{"id":"e0710d4a-4977-434d-8157-843274ca616d","type":"GlyphRenderer"}]},"id":"2638ac09-6723-49c5-97f3-dbd888e97b7f","type":"LegendItem"},{"attributes":{"active_drag":{"id":"f2e7ae96-f7c0-4ec8-aa89-1de5e2291ca8","type":"PanTool"},"active_inspect":"auto","active_scroll":{"id":"15268693-0e3a-48b2-975f-b0ea9dc09e23","type":"WheelZoomTool"},"active_tap":"auto","tools":[{"id":"f2e7ae96-f7c0-4ec8-aa89-1de5e2291ca8","type":"PanTool"},{"id":"15268693-0e3a-48b2-975f-b0ea9dc09e23","type":"WheelZoomTool"},{"id":"f8451a6d-2b4d-4eda-a03c-0fef22946bf1","type":"BoxZoomTool"},{"id":"cec2635d-824e-40e2-827e-d498825c9b80","type":"SaveTool"},{"id":"9e462b40-8e1e-498e-8413-e6a9c071323c","type":"ResetTool"},{"id":"645e8c3c-a3bf-4bbb-8ee1-f9b16d6a67d5","type":"HelpTool"}]},"id":"43f7d958-4dd4-4f4c-9a32-dfce99202a19","type":"Toolbar"},{"attributes":{},"id":"44d56b71-b43b-4089-8d79-392e80e0c46f","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"firebrick"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac5b160f-afdc-4d1e-bb0b-e801055ef062","type":"Line"},{"attributes":{"plot":{"id":"51df9eca-ea47-48b1-bb86-65321c775964","subtype":"Figure","type":"Plot"}},"id":"f2e7ae96-f7c0-4ec8-aa89-1de5e2291ca8","type":"PanTool"},{"attributes":{"callback ...

# %% [markdown]
# # Add all V class template stars
#
# For a given VIMOS source we can plot the VIMOS spectra and all spectral types. A total of 28 template spectra. In the future possible include other luminosity class and try to make the selection of the template a widget and not like right now that it is an interactive legend.
#
# It takes a long time to get the flux and wavelenght values to normalize the 28 spectra so only run the whole code if need to create again the template spectra to plot. To overlay the template star click on the name of the desired template to overlay. The names are as follow:
#
# | Spectral Type | Star name |
# |:-------------:|:---------:|
# | A0V           | HD 162305 |
# | A1V           |  HD 65810 |
# | A2V           |  HD 60178 (Castor) |
# | A3V           | HD 211998 |
# | A4V           | HD 145689 |
# | A5V           |  HD 39060 |
# | A7V           | HD 187642 (Altair) |
# | A9V           |  HD 26612 |
# | F0V           | HD 109931 |
# | F1V           |  HD 40136 |
# | F2V           |  HD 33256 |
# | F3V           |  HD 18692 |
# | F4V           |  HD 37495 |
# | F6V           |  HD 16673 |
# | F8V           |  HD 45067 |
# | F9V           |  HD 10647 |
# | G0V           | HD 105113 |
# | G1V           |  HD 20807 |
# | G2V           |  HD 14802 |
# | G3V           | HD 211415 |
# | G4V           |  HD 59967 |
# | G5V           |  HD 59468 |
# | G6V           | HD 140901 |
# | G9V           |  HD 25069 |
# | K2V           |  HD 22049 |
# | K5V           |  HD 10361 |
# | M0V           | HD 156274 |
# | M6V           |  HD 34055 |

# %%
#Dictionary of sources name and spectral type
dicsources={"hd162305":'A0V',"hd65810":'A1V', "Castor":"A2V",'hd211998':"A3V",
            "hd145689":'A4V',"hd39060":"A5V", "Altairus":'A7V', "hd26612":'A9V',
           "hd109931":'F0V',"hd40136":'F1V',"hd33256":"F2V","hd18692":"F3V",
           "hd37495":"F4V","hd16673":"F6V","hd45067":"F8V","hd10647":"F9V",
           "hd105113":"G0V","hd20807":"G1V","hd14802":"G2V","hd211415":"G3V",
           "hd59967":"G4V","hd59468":"G5V","hd140901":"G6V","hd25069":"G9V",
           "hd22049":"K2V","hd10361":"K5V","hd156274":"M0V","hd34055":"M6V"}

#To ordered the tempaltes by their spectral type I had to do in the command line:
# mv hd187642.tfits ltairus.tfits
# mv hd60178.tfits Castor.tfits


#Sort by spectral type:
dire = './stars' #Directory with all the template spectra
sortedlist = sorted(dicsources.items(), key=lambda t: t[1])
stars = [ i[0] for i in sortedlist]

#Can have one continuos color bar or a different one per spectral type
#colors = viridis(len(stars)) # colors map to plot
colors = BrBG8 + Accent8 + OrRd8 + Pastel2_4


#plot parameters
xr = (7700,8900)
yr = (0.5,1.4)
p =  figure(x_axis_label='Angstrom', y_axis_label='Y',title="Click on the desired stellar template to overplot", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=1000
             )
p.line(x=xcx, y=ycx,color='firebrick',line_width=4,line_alpha=0.8,legend='CX Source')

hover2 = HoverTool(
        tooltips=[
            ("(x,y)", "($x{1}, $y)"),
        ]
    )
p.add_tools(hover2)
p.add_tools(tools.ResizeTool())


#Loop over the stars to create plot them on Bokeh plot
#This loops take time so only run if the final product is not available
#if want to delete them to rerun the loop change delete to True:
deletealldata = False
if deletealldata:
    if  os.path.exists(sourcename+'cont.dispcor.fits'):
        os.remove(sourcename+'cont.dispcor.fits')
    if  os.path.exists(name+'.fits'):
        os.remove(name+'.fits') 
    if  os.path.exists(sourcename+'cont.fits'):
        os.remove(sourcename+'cont.fits')
        
        
for index, star in enumerate(stars):

    #Get template star table data
    t = fits.open("{}/{}.tfits".format(dire, star))
    #Get name of the star
    name= t[1].header['HIERARCH ESO OBS TARG NAME']
    sourcename = name
   

    if not os.path.exists(sourcename+'cont.txt'):
    
        # Get wavelenght and flux values
        data = t[1].data
        waveall = data['Wave']
        fluxall = data['Flux']
        #Get wavelenght and flux values near the VIMOS data
        equalwaves = []
        equalflux = []
        for i in xspectra:
            indx = np.where(abs(waveall-i) < 0.1)
            equalwaves.append(waveall[indx][0])
            equalflux.append(fluxall[indx][0])
        sourcename = name

        # Do the smoothing
        fluxgaussian10 = convolve(equalflux, Gaussian1DKernel(stddev=2))

            #Create a fits file from the data
        #name = 'fluxsmooth'
        if os.path.exists(name+'.fits'):
            os.remove(name+'.fits')
        hdu = fits.PrimaryHDU(fluxgaussian10)
        hdu.writeto(name+'.fits')
        data, header = fits.getdata(name+'.fits', header=True)
        header['NAXIS'] = 2
        header['NAXIS2'] = 2499
        header['CRVAL1'] = 3501.3
        header['CRPIX1'] = 1.
        header['CTYPE1'] = 'PIXEL'
        header['CTYPE2'] = 'LINEAR'
        header['CD1_1'] = 2.6
        header['CD2_2'] = 1.
        header
        fits.writeto(name+'.fits', data, header, overwrite=True)
        #Normalize the template smoothed and decimated
        sourcename = name
        sample = '*'
        if os.path.exists(sourcename+'cont.fits'):
            os.remove(sourcename+'cont.fits')
        iraf.noao.onedspec.continuum.setParam('input',sourcename+'.fits')
        iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
        iraf.noao.onedspec.continuum.setParam('interactive','no')
        iraf.noao.onedspec.continuum.setParam('sample',sample)
        iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
        iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')


        #Not sure if I need to do this
        if os.path.exists(sourcename+'cont.dispcor.fits'):
            os.remove(sourcename+'cont.dispcor.fits')

        iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
        iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

    x=[]
    y=[]
    with open(sourcename+'cont.txt') as f:
        for lines in f:
            x.append(float(lines.split()[0]))
            y.append(float(lines.split()[1]))
            
    #If you want to have the name and not the spectra type change legend=name
    t = p.line(x=x,y=y,color=colors[index], line_alpha=0.0, 
           line_width=4,legend=dicsources[name],muted_alpha=1.,muted_color=colors[index])
    #This is a very ideficient way to have the colors in the legend to show up by default. 
    t2 = p.line(x=x[0],y=y[0],color=colors[index], line_alpha=1.0, 
           line_width=4,legend=dicsources[name],muted_alpha=1.,muted_color=colors[index])

    
p.legend.location = "top_left"
p.legend.click_policy="mute"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="64876fcb-11b0-4740-b6be-2fe298224304"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("64876fcb-11b0-4740-b6be-2fe298224304");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("64876fcb-11b0-4740-b6be-2fe298224304");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '64876fcb-11b0-4740-b6be-2fe298224304' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af37924b-4016-4a26-9532-337c6af2b2f0":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3501.3,3503.9,3506.5,3509.1,3511.7,3514.3,3516.9,3519.5,3522.1,3524.7,3527.3,3529.9,3532.5,3535.1,3537.7,3540.3,3542.9,3545.5,3548.1,3550.7,3553.3,3555.9,3558.5,3561.1,3563.7,3566.3,3568.9,3571.5,3574.1,3576.7,3579.3,3581.9,3584.5,3587.1,3589.7,3592.3,3594.9,3597.5,3600.1,3602.7,3605.3,3607.9,3610.5,3613.1,3615.7,3618.3,3620.9,3623.5,3626.1,3628.7,3631.3,3633.9,3636.5,3639.1,3641.7,3644.3,3646.9,3649.5,3652.1,3654.7,3657.3,3659.9,3662.5,3665.1,3667.7,3670.3,3672.9,3675.5,3678.1,3680.7,3683.3,3685.9,3688.5,3691.1,3693.7,3696.3,3698.9,3701.5,3704.1,3706.7,3709.3,3711.9,3714.5,3717.1,3719.7,3722.3,3724.9,3727.5,3730.1,3732.7,3735.3,3737.9,3740.5,3743.1,3745.7,3748.3,3750.9,3753.5,3756.1,3758.7,3761.3,3763.9,3766.5,3769.1,3771.7,3774.3,3776.9,3779.5,3782.1,3784.7,3787.3,3789.9,3792.5,3795.1,3797.7,3800.3,3802.9,3805.5,3808.1,3810.7,3813.3,3815.9,3818.5,3821.1,3823.7,3826.3,3828.9,3831.5,3834.1,3836.7,3839.3,3841.9,3844.5,3847.1,3849.7,3852.3,3854.9,3857.5,3860.1,3862.7,3865.3,3867.9,3870.5,3873.1,3875.7,3878.3,3880.9,3883.5,3886.1,3888.7,3891.3,3893.9,3896.5,3899.1,3901.7,3904.3,3906.9,3909.5,3912.1,3914.7,3917.3,3919.9,3922.5,3925.1,3927.7,3930.3,3932.9,3935.5,3938.1,3940.7,3943.3,3945.9,3948.5,3951.1,3953.7,3956.3,3958.9,3961.5,3964.1,3966.7,3969.3,3971.9,3974.5,3977.1,3979.7,3982.3,3984.9,3987.5,3990.1,3992.7,3995.3,3997.9,4000.5,4003.1,4005.7,4008.3,4010.9,4013.5,4016.1,4018.7,4021.3,4023.9,4026.5,4029.1,4031.7,4034.3,4036.9,4039.5,4042.1,4044.7,4047.3,4049.9,4052.5,4055.1,4057.7,4060.3,4062.9,4065.5,4068.1,4070.7,4073.3,4075.9,4078.5,4081.1,4083.7,4086.3,4088.9,4091.5,4094.1,4096.7,4099.3,4101.9,4104.5,4107.1,4109.7,4112.3,4114.9,4117.5,4120.1,4122.7,4125.3,4127.9,4130.5,4133.1,4135.7,4138.3,4140.9,4143.5,4146.1,4148.7,4151.3,4153.9,4156.5,4159.1,4161.7,4164.3,4166.9,4169.5,4172.1,4174.7,4177.3,4179.9,4182.5,4185.1,4187.7,4190.3,4192.9,4195.5,4198.1,4200.7,4203.3,4205.9,4208.5,4211.1,4213.7,4216.3,4218.9,4221.5,4224.1,4226.7,4229.3,4231.9,4234.5,4237.1,4239.7,4242.3,4244.9,4247.5,4250.1,4252.7,4255.3,4257.9,4260.5,4263.1,4265.7,4268.3,4270.9,4273.5,4276.1,4278.7,4281.3,4283.9,4286.5,4289.1,4291.7,4294.3,4296.9,4299.5,4302.1,4304.7,4307.3,4309.9,4312.5,4315.1,4317.7,4320.3,4322.9,4325.5,4328.1,4330.7,4333.3,4335.9,4338.5,4341.1,4343.7,4346.3,4348.9,4351.5,4354.1,4356.7,4359.3,4361.9,4364.5,4367.1,4369.7,4372.3,4374.9,4377.5,4380.1,4382.7,4385.3,4387.9,4390.5,4393.1,4395.7,4398.3,4400.9,4403.5,4406.1,4408.7,4411.3,4413.9,4416.5,4419.1,4421.7,4424.3,4426.9,4429.5,4432.1,4434.7,4437.3,4439.9,4442.5,4445.1,4447.7,4450.3,4452.9,4455.5,4458.1,4460.7,4463.3,4465.9,4468.5,4471.1,4473.7,4476.3,4478.9,4481.5,4484.1,4486.7,4489.3,4491.9,4494.5,4497.1,4499.7,4502.3,4504.9,4507.5,4510.1,4512.7,4515.3,4517.9,4520.5,4523.1,4525.7,4528.3,4530.9,4533.5,4536.1,4538.7,4541.3,4543.9,4546.5,4549.1,4551.7,4554.3,4556.9,4559.5,4562.1,4564.7,4567.3,4569.9,4572.5,4575.1,4577.7,4580.3,4582.9,4585.5,4588.1,4590.7,4593.3,4595.9,4598.5,4601.1,4603.7,4606.3,4608.9,4611.5,4614.1,4616.7,4619.3,4621.9,4624.5,4627.1,4629.7,4632.3,4634.9,4637.5,4640.1,4642.7,4645.3,4647.9,4650.5,4653.1,4655.7,4658.3,4660.9,4663.5,4666.1,4668.7,4671.3,4673.9,4676.5,4679.1,4681.7,4684.3,4686.9,4689.5,4692.1,4694.7,4697.3,4699.9,4702.5,4705.1,4707.7,4710.3,4712.9,4715.5,4718.1,4720.7,4723.3,4725.9,4728.5,4731.1,4733.7,4736.3,4738.9,4741.5,4744.1,4746.7,4749.3,4751.9,4754.5,4757.1,4759.7,4762.3,4764.9,4767.5,4770.1,4772.7,4775.3,4777.9,4780.5,4783.1,4785.7,4788.3,4790.9,4793.5,4796.1,4798.7,4801.3,4803.9,4806.5,4809.1,4811.7,4814.3,4816.9,4819.5,4822.1,4824.7,4827.3,4829.9,4832.5,4835.1,4837.7,4840.3,4842.9,4845.5,4848.1,4850.7,4853.3,4855.9,4858.5,4861.1,4863.7,4866.3,4868.9,4871.5,4874.1,4876.7,4879.3,4881.9,4884.5,4887.1,4889.7,4892.3,4894.9,4897.5,4900.1,4902.7,4905.3,4907.9,4910.5,4913.1,4915.7,4918.3,4920.9,4923.5,492 ...

# %% [markdown]
# # Still to do
#
# - [ ] Check the normalization for the CX sources
# - [ ] Check how to do the shift on the wavelenghts
# - [ ] Include other luminosities classes.
# - [ ] Mask emission lines, DIBs, and telluric features
# - [ ] Correctly do downsampling by decimation
# - [ ] Try other Downsampling methods like by interpolation
# - [ ] Check the right value for the Gaussian Smoothing
# - [ ] Do the $\chi ^2$ with the residuals
# - [ ] Better way to display legends

# %% [markdown]
# # References
#
# Jianfeng Wu, P. G. Jonker, M. A. P. Torres, C. T. Britt, C. B. Johnson, R. I. Hynes, S. Greiss, D. T. H. Steeghs, T. J. Maccarone, C. O. Heinke, T. Wevers; Gemini spectroscopy of Galactic Bulge Sources: a population of hidden accreting binaries revealed?. Mon Not R Astron Soc 2015; 448 (2): 1900-1915. doi: https://doi.org/10.1093/mnras/stv047
#
# Jehin, E., Bagnulo, S., Melo, C., Ledoux, C., & Cabanac, R. (2005). The UVES Paranal Observatory Project: a public library of high resolution stellar spectra. Proceedings of the International Astronomical Union, 1(S228), 261–262. http://doi.org/10.1017/S1743921305005739
#
# Kurucz R. L., 2006, preprint (arXiv:https://arxiv.org/abs/astro-ph/0605029)
#
# Wallace L., Hinkle K. H., Livingston W. C., Davis S. P., 2011, ApJS, 195, 6 http://dx.doi.org/10.1088/0067-0049/195/1/6
