# %% [markdown]
# # CX 25
#
# As it can be seen [here](https://vimos.manuelpm.me/cx25) and mentioned [here](http://manuelpm.me/VIMOSlabbook/log/2017/05/25/CX25.html) there are two souces in the slit of CX25.

# %%
#Import packages
from astropy.io import fits
import os
from stsci.tools import capable
capable.OF_GRAPHICS = False
from pyraf import iraf
import numpy as np
from shutil import copyfile
from astropy.convolution import convolve, Box1DKernel
#Bokeh plotting
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span, Label, Arrow, NormalHead
from bokeh.models import HoverTool, tools, ColumnDataSource, CustomJS, Slider, BoxAnnotation
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6ed3653e-3d74-4b90-a174-30b3be7e84bf">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Defining the extraction parameters
#
# First we define the parameters to extract the desire spectra:
#     - Name of the source
#     - Center, low and upper limits of the aperture
#     - background sample

# %% [markdown]
# # First Source
#
# We begin with the first souce in the corner of the slit.

# %%
sourcename = 'cx25sky'
center = 119
low = -5
high = 5
b_low = [center-90,center-70]
b_up = [143-center,152-center]
databasegeneral = 'database/apcx25sexm'
filename = 'database/ap'+sourcename
fitsfilename = 'VI_SSEM_577734_2011-06-24T05:56:42.518_G475_MR_402230_Q4_hi.fits'

# %% [markdown]
# ## Exposure time
#
# First we multiply the 2D spectra times the exposure time

# %%
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    

iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)

# %% [markdown]
# ##  Define apertures and backgrpund sample in the database
#
# Now we need to change the database of the aperture to define the center. This is the only way I have found to do it automatically. After this define the parameters in the .par file

# %%
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagename= lines.split()[1]
        if 'center' in lines:
                numerocenter = lines.split()[2]
        if 'low' in lines:
                numerolow = lines.split()[2]
        if 'high' in lines:
                numerohigh = lines.split()[2]
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagename,sourcename)
filedata = filedata.replace(numerocenter,str(center))
filedata = filedata.replace(numerolow,str(low))
filedata = filedata.replace(numerohigh,str(high))
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

# %% [markdown]
# ## Calling Apall

# %%
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
#try output
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %% [markdown]
# ## Plotting with Bokeh
#
# Plot the text file after doing dispcor and exporting the spectra to a text file.

# %%
#Plotting
##For srfm[0].header["CTYPE1"] = 'LINEAR'
#Other way
#srfm = fits.open(sourcename+'.ms.fits')
#secondstar = srfm[0].data#[0][0]##[0][0] if using clean
#secondstar = srfm[0].data[0][0]
#xn = srfm[0].header["NAXIS1"]
#refx = srfm[0].header["CRVAL1"]
#step = srfm[0].header['CD1_1']
#cr = srfm[0].header['CRPIX1']
#
#xlist = [ refx + step*(i - cr) for i in np.arange(1, len(secondstar)+1) ]
#Create ColumnDataSource
#x = np.array(xlist)
#y = np.array(secondstar)

#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
#Eraaseplot.line(xlist,secondstar)
plot.line('x','y',source=source)
show(plot)
# Out:
# cx25sky.ms.fits: Resampling using current coordinate system
# cx25sky.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ad86ea3d-d23f-4ed4-97b4-095e0cc1040f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ad86ea3d-d23f-4ed4-97b4-095e0cc1040f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad86ea3d-d23f-4ed4-97b4-095e0cc1040f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 
},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3501.3,3503.9,3506.5,3509.1,3511.7,3514.3,3516.9,3519.5,3522.1,3524.7,3527.3,3529.9,3532.5,3535.1,3537.7,3540.3,3542.9,3545.5,3548.1,3550.7,3553.3,3555.9,3558.5,3561.1,3563.7,3566.3,3568.9,3571.5,3574.1,3576.7,3579.3,3581.9,3584.5,3587.1,3589.7,3592.3,3594.9,3597.5,3600.1,3602.7,3605.3,3607.9,3610.5,3613.1,3615.7,3618.3,3620.9,3623.5,3626.1,3628.7,3631.3,3633.9,3636.5,3639.1,3641.7,3644.3,3646.9,3649.5,3652.1,3654.7,3657.3,3659.9,3662.5,3665.1,3667.7,3670.3,3672.9,3675.5,3678.1,3680.7,3683.3,3685.9,3688.5,3691.1,3693.7,3696.3,3698.9,3701.5,3704.1,3706.7,3709.3,3711.9,3714.5,3717.1,3719.7,3722.3,3724.9,3727.5,3730.1,3732.7,3735.3,3737.9,3740.5,3743.1,3745.7,3748.3,3750.9,3753.5,3756.1,3758.7,3761.3,3763.9,3766.5,3769.1,3771.7,3774.3,3776.9,3779.5,3782.1,3784.7,3787.3,3789.9,3792.5,3795.1,3797.7,3800.3,3802.9,3805.5,3808.1,3810.7,3813.3,3815.9,3818.5,3821.1,3823.7,3826.3,3828.9,3831.5,3834.1,3836.7,3839.3,3841.9,3844.5,3847.1,3849.7,3852.3,3854.9,3857.5,3860.1,3862.7,3865.3,3867.9,3870.5,3873.1,3875.7,3878.3,3880.9,3883.5,3886.1,3888.7,3891.3,3893.9,3 ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

# %% [markdown]
# ## Plotting the normalize spectra
#
# We first define the desired range for the initial zoom:

# %%
#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
# Out:
# cx25skycont.fits: Resampling using current coordinate system
# cx25skycont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
# GlyphRenderer(id='fe71fb75-2a94-4c37-b074-f472fbfd6c60', ...)

# %% [markdown]
# ## Overplot lines
#
# If desired we can define several know emission and absoprtion lines to overplot to the normalize spectra

# %%
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0f617081-5556-451c-b007-233e767e1b74"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0f617081-5556-451c-b007-233e767e1b74");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0f617081-5556-451c-b007-233e767e1b74");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0f617081-5556-451c-b007-233e767e1b74' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f8dcb0e-ff8a-4f73-9d90-16c940b2e1a7":{"roots":{"references":[{"attributes":{"end":{"id":"79616139-5234-4036-82e6-56fe956169e6","type":"NormalHead"},"plot":{"id":"b2eca586-995d-4c5e-9baf-e738a9839aa6","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8688},"x_start":{"value":8688},"y_end":{"value":0.9872730000000001},"y_start":{"value":0.8672730000000001}},"id":"be7a5152-d342-431f-b9d0-71d5cf5f22ed","type":"Arrow"},{"attributes":{},"id":"65c4d570-c8d2-430d-b171-83bbd7c4dcaa","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"62ddbf0e-a223-48ec-88ff-af63884c17a6","type":"NormalHead"},{"attributes":{"end":{"id":"b140b95f-7702-4ba5-a4fc-9e915e04b12a","type":"NormalHead"},"plot":{"id":"b2eca586-995d-4c5e-9baf-e738a9839aa6","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":6497},"x_start":{"value":6497},"y_end":{"value":0.9102972},"y_start":{"value":0.7902972}},"id":"623d2388-c2ee-4d7d-8048-5be458c6cec6","type":"Arrow"},{"attributes":{"below":[{"id":"20a5a975-270d-4def-ace2-d2b1dd2263dc","type":"LinearAxis"}],"left":[{"id":"1e3a3571-15a8-49e3-9b0e-d2011815340c","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"20a5a975-270d-4def-ace2-d2b1dd2263dc","type":"LinearAxis"},{"id":"864cf482-70fb-4e7b-acc0-a4d0b778310a","type":"Grid"},{"id":"1e3a3571-15a8-49e3-9b0e-d2011815
subtype":"Figure","type":"Plot"},{"attributes":{},"id":"95c60f94-51cf-4295-b494-055804ec5959","type":"ToolEvents"},{"attributes":{"end":{"id":"243507ee-15bf-4740-9c09-6e37ffff61cb","type":"NormalHead"},"plot":{"id":"b2eca586-995d-4c5e-9baf-e738a9839aa6","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8446},"x_start":{"value":8446},"y_end":{"value":0.9845980000000001},"y_start":{"value":0.8645980000000001}},"id":"a628f87e- ...

# %% [markdown]
# # Second source in the slit
#
# This one is centered around 166 and as can it be seen [here](https://vimos.manuelpm.me/cx25), it is saturared.

# %%
sourcename = 'cx25skyatc66'
center = 170
low = -5
high = 5
b_low = [center-150,center-140]
b_up = [180-center,175-center]
databasegeneral = 'database/apcx25sexm'
filename = 'database/ap'+sourcename
fitsfilename = 'VI_SSEM_577734_2011-06-24T05:56:42.518_G475_MR_402230_Q4_hi.fits'

# %% [markdown]
# ## Exposure time
#
# First we multiply the 2D spectra times the exposure time

# %%
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    

iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)

# %% [markdown]
# ##  Define apertures and backgrpund sample in the database
#
# Now we need to change the database of the aperture to define the center. This is the only way I have found to do it automatically. After this define the parameters in the .par file

# %%
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagename= lines.split()[1]
        if 'center' in lines:
                numerocenter = lines.split()[2]
        if 'low' in lines:
                numerolow = lines.split()[2]
        if 'high' in lines:
                numerohigh = lines.split()[2]
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagename,sourcename)
filedata = filedata.replace(numerocenter,str(center))
filedata = filedata.replace(numerolow,str(low))
filedata = filedata.replace(numerohigh,str(high))
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

# %% [markdown]
# ## Calling Apall

# %%
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
#try output
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %% [markdown]
# ## Plotting with Bokeh
#
# Plot the text file after doing dispcor and exporting the spectra to a text file.

# %%
#Plotting
##For srfm[0].header["CTYPE1"] = 'LINEAR'
#Other way
#srfm = fits.open(sourcename+'.ms.fits')
#secondstar = srfm[0].data#[0][0]##[0][0] if using clean
#secondstar = srfm[0].data[0][0]
#xn = srfm[0].header["NAXIS1"]
#refx = srfm[0].header["CRVAL1"]
#step = srfm[0].header['CD1_1']
#cr = srfm[0].header['CRPIX1']
#
#xlist = [ refx + step*(i - cr) for i in np.arange(1, len(secondstar)+1) ]
#Create ColumnDataSource
#x = np.array(xlist)
#y = np.array(secondstar)

#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
#Eraaseplot.line(xlist,secondstar)
plot.line('x','y',source=source)
show(plot)
# Out:
# cx25skyatc66.ms.fits: Resampling using current coordinate system
# cx25skyatc66.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6f675b76-eb26-49f9-87dd-c0d2e5eb4b19"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6f675b76-eb26-49f9-87dd-c0d2e5eb4b19");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f675b76-eb26-49f9-87dd-c0d2e5eb4b19");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f675b76-eb26-49f9-87dd-c0d2e5eb4b19' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0e90a550-4c94-46c9-8359-f85633b09ec0":{"roots":{"references":[{"attributes":{"plot":{"id":"4d7cd931-14b9-4315-95ef-e788dd4c0263","subtype":"Figure","type":"Plot"}},"id":"63e52636-2e8e-4ae0-84e5-e90ced0d0cc1","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":
":"BoxAnnotation"},{"id":"9456c615-8f35-4919-a7d7-40c9abdfe282","type":"GlyphRenderer"}],"title":{"id":"fcba0d95-baf6-40c4-a5e7-2414ec5c53e3","type":"Title"},"tool_events":{"id":"a6b22d14-da0f-4fe0-a2f1-55133d5b9d74","type":"ToolEvents"},"toolbar":{"id":"f601fc9c-9634-4fb4-80bf-e67a8b96a1fc","type":"Toolbar"},"x_range":{"id":"726ff945-c45d-4dad-bdfd-c5c679e62993","type":"DataRange1d"},"y_range":{"id":"85168657-9120-40a6-8f4a-75a969ca5723","type":"DataRange1d"}},"id":"4d7cd931-14b9-4315-95ef-e788dd4c0263","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"4d7cd931-14b9-4315-95ef-e788dd4c0263","subtype":"Figure","type":"Plot"}},"id":"eb130323-aa96-4b33-8e0b-393fc03d5e69","type":"HelpTool"},{"attributes":{},"id":"dbb79cef-62c8-4b84-be31-fc9d0ccab9ab","type":"BasicTicker"},{"attributes":{"overlay":{"id":"d2686a19-2e62-431b-a2ed-ff3f9a5f78d6","type":"BoxAnnotation"},"plot":{"id":"4d7cd931-14b9-4315-95ef-e788dd4c0263","subtype":"Figure","type" ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

# %% [markdown]
# ## Plotting the normalize spectra
#
# We first define the desired range for the initial zoom:

# %%
#Plotting
xr = (6100,8900)
yr = (0.4,1.4)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
# Out:
# cx25skyatc66cont.fits: Resampling using current coordinate system
# cx25skyatc66cont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
# GlyphRenderer(id='13174604-4e55-4b76-9c76-2eea7290613b', ...)

# %% [markdown]
# ## Overplot lines
#
# If desired we can define several know emission and absoprtion lines to overplot to the normalize spectra

# %%
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="68631e24-d0ea-434c-95ae-e6142441e3e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("68631e24-d0ea-434c-95ae-e6142441e3e4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("68631e24-d0ea-434c-95ae-e6142441e3e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '68631e24-d0ea-434c-95ae-e6142441e3e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"24df5a9a-f7d5-4cf3-95fd-5005a613317c":{"roots":{"references":[{"attributes":{"callback":null,"end":1.4,"start":0.4},"id":"65add660-3bcb-4d9c-9594-e64bdb43e8fd","type":"Range1d"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"9f79ab55-7c83-4cc7-973d-9f1631ba9d22","type":"NormalHead"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"38aece06-2411-4105-97c0-69eaec45409c","type":"NormalHead"},{"attributes":{},"id":"ba9ae2a0-61de-4261-b842-ca230fc6afac","type":"BasicTickFormatter"},{"attributes":{"end":{"id":"daa89ed8-c557-484d-befb-6bf43863fbb5","type":"NormalHead"},"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8621},"x_start":{"value":8621},"y_end":{"value":0.9592746999999999},"y_start":{"value":0.8392746999999999}},"id":"9356e392-23ce-48ce-a14c-7d28e9be74ed","type":"Arrow"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"7ec3e0ce-0c03-4b36-93b0-1041db8e9dd3","type":"NormalHead"},{"attributes":{"end":{"id":"38aece06-2411-4105-97c0-69eaec45409c","type":"NormalHead"},"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8688},"x_start":{"value":8688},"y_end":{"value":0.9692548999999999},"y_start":{"value":0.8492548999999999}},"id":"e0021942-b683-4e54-96ed-13ce7f82f8e1","type":"Arrow"},{"attributes":{"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"text":"Ca II","x":8498,"y":0.902439},"id":"cc7b7cdf-34c1-4299-8b2c-7de0f67bf3b1","type":"Label"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"68c9b9cc-e51c-4cf1-8fa7-c1c614917a07","type":"NormalHead"},{"attributes":{"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"}},"id":"bea619c3-c657-40fc-9aaa-dca6bbcf604b","type":"PanTool"},{"attributes":{"end":{"id":"ba36bc5d-920b-4162-84da-2feb38dbada1","type":"NormalHead"},"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8662},"x_start":{"value":8662},"y_end":{"value":0.8805843},"y_start":{"value":0.7605843}},"id":"5124eeac-e18c-41cd-9888-6bbc46c4e496","type":"Arrow"},{"attributes":{"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"}},"id":"5faaaf80-b37c-4fa5-a9f7-41811d9b41f9","type":"ResetTool"},{"attributes":{"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"}},"id":"3e695f55-7b48-4c9f-81c3-aa5937b0f483","type":"WheelZoomTool"},{"attributes":{"end":{"id":"7ec3e0ce-0c03-4b36-93b0-1041db8e9dd3","type":"NormalHead"},"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8468},"x_start":{"value":8468},"y_end":{"value":0.9516155},"y_start":{"value":0.8316155}},"id":"c9bcc019-8e7a-4c28-a9a0-a210f442b9f1","type":"Arrow"},{"attributes":{"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"text":"Mg I","x":8807,"y":0.9814970000000001},"id":"b4ad7079-ab52-457d-8e7c-257b84a946b5","type":"Label"},{"attributes":{"end":{"id":"1b057e0c-205d-477b-82fb-a9f872dbcfac","type":"NormalHead"},"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8446},"x_start":{"value":8446},"y_end":{"value":0.9580361},"y_start":{"value":0.8380361}},"id":"aeee4afe-8738-4406-9bd8-aacfa8b01c11","type":"Arrow"},{"attributes":{"end":{"id":"fc310d46-4f98-40d4-b7e8-b1d6c298b0d7","type":"NormalHead"},"plot":{"id":"e9406a28-05ba-44e1-95c4-37c8d70716c2","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8807},"x_start":{"value":8807},"y_end":{"value":0.9814970000000001},"y_start":{"value":0.8614970000000001}},"id":"b41ac71e-64e7-41fe-8f41-36f54a849ec1","type":"Arrow"} ...
