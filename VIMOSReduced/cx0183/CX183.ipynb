# %% [markdown]
# # CX183
#
# There is only one source in the preimage. It corresponds to the biggest section on the 2D spectra from 63 to around 170. Check https://vimos.manuelpm.me/cx183. Two sources seem to be very close together.
#
#
# ![](images/precx183.png)![](images/2dcx183.png)
#
#
# - - -
#
#
# ## Information
#
# Mentioned as [2RXP J175041.2-291644 -](http://simbad.u-strasbg.fr/simbad/sim-id?Ident=%406169479&Name=2RXP%20J175041.2-291644&submit=submit)
#
#
# In (Hynes et al. 2012):
#
# > CX156, CX183, CX256, CX275, and CX863 all suffer from mild saturation, but we can still exclude large amplitude variability in these objects
#
# In the preprint:
#
# > A2 V (Tycho-2) from (Hynes et al. 2012)
#
#
# and cites the
#
# Only cites THe GBs aper.[here](http://vizier.u-strasbg.fr/viz-bin/VizieR-5?-ref=VIZ58842c132320&-out.add=.&-source=J/ApJS/194/18/table3&recno=183)
#
# 12 counts
#
# 12 counts
#
# In the “Sources from Pointed ROSAT Observations that Fall in the GBS Area” (Jonker et al. 2011)

# %% [markdown]
# # Spectrum extraction
#
# First import the require packages

# %%
from astropy.io import fits
import os
from stsci.tools import capable
capable.OF_GRAPHICS = False
from pyraf import iraf
import numpy as np
from shutil import copyfile
#Bokeh plotting
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span, Label, Arrow, NormalHead
from bokeh.models import HoverTool, tools, ColumnDataSource, CustomJS, Slider, BoxAnnotation
output_notebook()
# Out:
# Created directory /root/VIMOSReduced/cx0183/pyraf for cache
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dae9b4b2-db36-48cb-9190-e7ed7bf553cd">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Defining the extraction parameters
#
# First we define the parameters to extract the desire spectra:
#     - Name of the extracted spectrum
#     - Center, low and upper limits of the aperture
#     - Background sample. Note that the background coordinates are relative to the aperture center and not image pixel coordinates so the endpoints need not be integer.
#     - 2D spectra to use. Can use the SSEM or SEXM. The SSEM doesnt have the sky substracted, and the background substraction can be done with IRAF and apall. SEXM has the background substracted by the VIMOS pipeline so background can be set to none
#
# To check what values can the website: https://vimos.manuelpm.me/

# %% [markdown]
# ## First fainter source

# %%
sourcename = 'cx183sky'
center = 116
low = -3
high = 1
b_low = [70-center,100-center]
b_up = [0,0]
databasegeneral = 'database/apcx183'
filename = 'database/ap'+sourcename
fitsfilename = 'mos_science_sky_extracted_Q3.fits'

# %% [markdown]
# ## Exposure time
#
# First we multiply the 2D spectra times the exposure time

# %%
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)
# Out:
#       +------------------------------------------------------------+
#       |       Space Telescope Science Data Analysis System         |
#       |                   STSDAS Version 3.17                      |
#       |                                                            |
#       |   Space Telescope Science Institute, Baltimore, Maryland   |
#       |   Copyright (C) 2014 Association of Universities for       |
#       |            Research in Astronomy, Inc.(AURA)               |
#       |       See stsdas$copyright.stsdas for terms of use.        |
#       |         For help, send e-mail to help@stsci.edu            |
#       |                                                            |
#       +------------------------------------------------------------+
# stsdas/:
#  analysis/      examples        hst_calib/      sobsolete/
#  contrib/       fitsio/         playpen/        toolbox/
#  describe       graphics/       problems

# %% [markdown]
# ##  Define apertures and background sample in the database
#
# We need to change the database of the aperture to define the center, lower and upper limit. Also to define the parameters of the background region to do the background substraction. This is the only way I have found to do it automatically. After this define the parameters in the .par file

# %%
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# # Tue 00:16:33 14-Mar-2017
# begin	aperture cx183 1 1250. 128.9408
# 	image	cx183sky
# 	aperture	1
# 	beam	1
# 	center	1250. 116
# 	low	-1249. -3
# 	high	1250. 1
# 	background
# 		xmin -46
# 		xmax 0
# 		function chebyshev
# 		order 1
# 		sample -46:-16,0:0
# 		naverage -3
# 		niterate 0
# 		low_reject 3.
# 		high_reject 3.
# 		grow 0.
# 	axis	2
# 	curve	5
# 		2.
# 		1.
# 		1.
# 		2500.
# 		0.

# %% [markdown]
# ## Calling Apall
#
# Now we define the parameters of apall, save it to the .par file and call the apall function.

# %%
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')
# Out:
# twodspec/:
#  apextract/     longslit/
# apextract/:
#  apall          apedit          apflatten       apnormalize     apscatter
#  apdefault@     apfind          apmask          aprecenter      apsum
#  apdemos/       apfit           apnoise         apresize        aptrace

# %% [markdown]
# ## Plotting with Bokeh
#
# Plot the text file after doing dispcor and exporting the spectra to a text file using the iraf routine wspectext.

# %%
#Plotting
##For srfm[0].header["CTYPE1"] = 'LINEAR'
#Other way
#srfm = fits.open(sourcename+'.ms.fits')
#secondstar = srfm[0].data#[0][0]##[0][0] if using clean
#secondstar = srfm[0].data[0][0]
#xn = srfm[0].header["NAXIS1"]
#refx = srfm[0].header["CRVAL1"]
#step = srfm[0].header['CD1_1']
#cr = srfm[0].header['CRPIX1']
#
#xlist = [ refx + step*(i - cr) for i in np.arange(1, len(secondstar)+1) ]
#Create ColumnDataSource
#x = np.array(xlist)
#y = np.array(secondstar)

#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# cx183sky.ms.fits: Resampling using current coordinate system
# cx183sky.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b368aa02-6edb-470b-a498-a82005524055"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b368aa02-6edb-470b-a498-a82005524055");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b368aa02-6edb-470b-a498-a82005524055");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b368aa02-6edb-470b-a498-a82005524055' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f93dddf7-b668-40b6-8255-4d6916f70c14":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8d0e0609-2610-4af2-a2da-0398a8477a0f","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"8600c329-131c-4ba9-97c6-fdd87b0b39b8","type":"ColumnDataSource"},"glyph":{"id":"88f6d42f-27c1-4161-9712-732b0e136850","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9317f0d5-d523-4d61-8f51-42e0ed3a6476","type":"Line"},"selection_glyph":null},"id":"8eee9a5e-96c4-4f2b-ad46-d0f6bd6530fe","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5b348696-3f23-4ce7-a710-96b0440a5a53","subtype":"Figure","type":"Plot"}},"id":"b97c146b-a8ec-4eba-b894-cd508ce495d6","type":"WheelZoomTool"},{"attributes":{},"id":"2e0556eb-c8ea-45d3-b453-51baa0b0e830","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5b348696-3f23-4ce7-a710-96b0440a5a53","subtype":"Figure","type":"Plot"}},"id":"78a5eef4-40d8-43f7-926f-4f753e80e05e","type":"HelpTool"},{"attributes":{},"id":"867892e4-d162-4c76-9a0e-db3498cf7231","type":"BasicTicker"},{"attributes":{},"id":"e9c5180e-627c-4df7-a8f6-ba7ce2f64da9","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"88f6d42f-27c1-4161-9712-732b0e136850","type":"Line"},{"attributes":{"below":[{"id":"60d65aba-774b-4f54-b22b-5663dc0dd866","type":"LinearAxis"}],"left":[{"id":"0baf146b-409f-4b18-9b09-bedc6daf8ac0","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"60d65aba-774b-4f54-b22b-5663dc0dd866","type":"LinearAxis"},{"id":"e94bfeb6-87d5-4000-a8e1-af5ac26dbf67","type":"Grid"},{"id":"0baf146b-409f-4b18-9b09-bedc6daf8ac0","type":"LinearAxis"},{"id":"6c28a17d-ea12-41fd-a2dd-92e4a7800a46","type":"Grid"},{"id":"8d0e0609-2610-4af2-a2da-0398a8477a0f","type":"BoxAnnotation"},{"id":"8eee9a5e-96c4-4f2b-ad46-d0f6bd6530fe","type":"GlyphRenderer"}],"title":{"id":"1051d92e-0e2e-4fbc-b5bc-89ecf7bc3dba","type":"Title"},"tool_events":{"id":"ed6b53c1-7981-40ee-991b-03896ecc43a6","type":"ToolEvents"},"toolbar":{"id":"9d85e5a0-3762-42f9-b704-2a3ad6b8f729","type":"Toolbar"},"x_range":{"id":"731d95b4-048d-4e9b-82e8-17d74d6eafc8","type":"DataRange1d"},"y_range":{"id":"72c0e6b4-070d-483b-b999-4cb4201768d9","type":"DataRange1d"}},"id":"5b348696-3f23-4ce7-a710-96b0440a5a53","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Spectra"},"id":"1051d92e-0e2e-4fbc-b5bc-89ecf7bc3dba","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"5b348696-3f23-4ce7-a710-96b0440a5a53","subtype":"Figure","type":"Plot"},"tooltips":[["(x,y)","($x{1.11}, $y)"]]},"id":"56f0869d-a3df-4e95-8492-939be162e8f9","type":"HoverTool"},{"attributes":{"callback":null},"id":"72c0e6b4-070d-483b-b999-4cb4201768d9","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3501.3,3503.9,3506.5,3509.1,3511.7,3514.3,3516.9,3519.5,3522.1,3524.7,3527.3,3529.9,3532.5,3535.1,3537.7,3540.3,3542.9,3545.5,3548.1,3550.7,3553.3,3555.9,3558.5,3561.1,3563.7,3566.3,3568.9,3571.5,3574.1,3576.7,3579.3,3581.9,3584.5,3587.1,3589.7,3592.3,3594.9,3597.5,3600.1,3602.7,3605.3,3607.9,3610.5,3613.1,3615.7,3618.3,3620.9,3623.5,3626.1,3628.7,3631.3,3633.9,3636.5,3639.1,3641.7,3644.3,3646.9,3649.5,3652.1,3654.7,3657.3,3659.9,3662.5,3665.1,3667.7,3670.3,3672.9,3675.5,3678.1,3680.7,3683.3,3685.9,3688.5,3691.1,3693.7,3696.3,3698.9,3701.5,3704.1,3706.7,3709.3,3711.9,3714.5,3717.1,3719.7,3722.3,3724.9,3727.5,3730.1,3732.7,3735.3,3737.9,3740.5,3743.1,3745.7,3748.3,3750.9,3753.5,3756.1,3758.7,3761.3,3763.9,3766.5,3769.1,3771.7,3774.3,3776.9,3779.5,3782.1,3784.7,3787.3,3789.9,3792.5,3795.1,3797.7,3800.3,3802.9,3805.5,3808.1,3810.7,3813.3,3815. ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

# %% [markdown]
# ## Plotting the normalize spectra
#
# We first define the desired range for the initial zoom:

# %%
#Plotting
xr = (8400,8900)
yr = (0.5,1.4)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
# Out:
# cx183skycont.fits: Resampling using current coordinate system
# cx183skycont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
# GlyphRenderer(id='41187d77-2ec8-4464-8bbf-62c7ed31db0f', ...)

# %% [markdown]
# ## Overplot lines
#
# If desired we can define several know emission and absoprtion lines to overplot to the normalize spectra

# %%
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,
            line('O I'):8446,line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('O I Triplet(72,74,75)'):7774,line('He I'):7065,
            line('P16'):8502,line('P15'):8545,line('P14'):8598,line('P13'):8665,
            line('P12'):8750,line('P11'):8863,line('P10'):9015,line('P9'):9229,
            line('P8'):9546,line('P17'):8467,line('P18'):8438,line('P19'):8413,line('P20'):8392}
  

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f1610688-afcf-4075-bb8c-c66d7b831c58"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f1610688-afcf-4075-bb8c-c66d7b831c58");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f1610688-afcf-4075-bb8c-c66d7b831c58");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f1610688-afcf-4075-bb8c-c66d7b831c58' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5512dc15-f78e-4da2-aeaf-7148148ad85d":{"roots":{"references":[{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"P10","x":9015,"y":0.7437819999999999},"id":"d960e4ab-e5c9-4eec-9f30-6ddcc6c6c753","type":"Label"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"}},"id":"a383b112-b20b-4f3c-bf54-25d44a92435c","type":"ResetTool"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"4f36530f-fa37-4292-ad21-523cf6276134","type":"NormalHead"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"d549ca0b-393c-413e-8f61-f70e391a8109","type":"NormalHead"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"H\u03b1","x":6563,"y":0.6186844},"id":"d2739b4d-630d-4300-938d-7778786c402e","type":"Label"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"}},"id":"50934be1-c254-47d6-bb85-134bfa89bc3d","type":"ResizeTool"},{"attributes":{"end":{"id":"9a364693-0ac0-415b-a305-380b599ce8a5","type":"NormalHead"},"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8665},"x_start":{"value":8665},"y_end":{"value":0.8256428},"y_start":{"value":0.7056428}},"id":"1849747b-ddfe-4813-944c-ddf6e596af70","type":"Arrow"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"34d7e04a-2f1f-4f00-a6c4-765f04bb75f5","type":"NormalHead"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"P15","x":8545,"y":0.8337618},"id":"8004a5b6-87cd-4a37-8c8b-335bd4e6ccaf","type":"Label"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"b161decb-5c3a-4d65-ac54-2cb45998062e","type":"NormalHead"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"P12","x":8750,"y":0.9453365},"id":"03434505-6bd7-4636-a0c3-3f444099005b","type":"Label"},{"attributes":{"plot":null,"text":"Spectra"},"id":"2dae1f57-7e2a-4f44-adc6-8c2ee0191feb","type":"Title"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"P8","x":9546,"y":0.39387740000000004},"id":"c67ee200-4081-4d29-85e6-2074d745c491","type":"Label"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6d25f453-fa73-463d-82e6-fea8b03c5173","type":"Line"},{"attributes":{"end":{"id":"88a79aa9-7fb0-4d2e-82f8-eafbd710e9c2","type":"NormalHead"},"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8863},"x_start":{"value":8863},"y_end":{"value":0.8882066},"y_start":{"value":0.7682066}},"id":"49b26d1f-e8f7-4dbd-8b47-0f2412b8e22d","type":"Arrow"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"P14","x":8598,"y":0.9588629},"id":"d64fad59-dab6-4f19-ac63-72bd83536b72","type":"Label"},{"attributes":{"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"text":"O I","x":8446,"y":0.9685455},"id":"9863f873-a115-4929-b3f5-8ede6ab8aab9","type":"Label"},{"attributes":{"overlay":{"id":"7a2dc53e-fc38-40bf-9377-5e7fd6f61dfe","type":"BoxAnnotation"},"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"}},"id":"321e0f25-ba94-4a2c-a1b1-5a327cc5075d","type":"BoxZoomTool"},{"attributes":{"end":{"id":"878e82fd-092c-468b-8fdc-362c4f615abc","type":"NormalHead"},"plot":{"id":"dcee0930-2100-4881-9f7d-bb1485ec99a4","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8446},"x_start":{"value":8446},"y_end":{"value":0.9685455},"y_start":{"value":0.8485455}},"id":"81fdc07d-fad3-4762-92c9-628e6b9d32db","type":"Arrow"},{"attributes":{"plot":{"id":"d ...

# %% [markdown]
# # The spectrum

# %% [markdown]
# # References
#
# Hynes, R. I., N. J. Wright, T. J. Maccarone, P. G. Jonker, S. Greiss, D. Steeghs, M. A. P. Torres, C. T. Britt, and G. Nelemans. 2012. “Identification of Galactic Bulge Survey X-Ray Sources with Tycho-2 Stars.” The Astrophysical Journal 761 (December): 162. doi:10.1088/0004-637X/761/2/162.
