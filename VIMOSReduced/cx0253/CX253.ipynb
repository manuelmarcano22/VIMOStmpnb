# %% [markdown]
# # CX253
#
# In the folder ther are at least 4 sources and 5 sections in the SEXM
#
#
# ![](images/cx253pre.png)
#
# ![](images/cx253sexm.png)
#
#
# CX253: It is the brigtest one from 50 to 100. Maybe two sources? Can see at aperture index 2499.
#
# - - -
#
# ## Information
#
# In the draft it is classified as a possible red dwarf

# %% [markdown]
# # Spectrum extraction
#
# First import the require packages

# %%
from astropy.io import fits
import os
from stsci.tools import capable
capable.OF_GRAPHICS = False
from pyraf import iraf
import numpy as np
from shutil import copyfile
#Bokeh plotting
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span, Label, Arrow, NormalHead
from bokeh.models import HoverTool, tools, ColumnDataSource, CustomJS, Slider, BoxAnnotation
output_notebook()
# Out:
# Created directory /root/VIMOSReduced/cx0253/pyraf for cache
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3bbca557-a039-461e-845b-72a39c0a61f4">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Defining the extraction parameters
#
# First we define the parameters to extract the desire spectra:
#     - Name of the extracted spectrum
#     - Center, low and upper limits of the aperture
#     - Background sample. Note that the background coordinates are relative to the aperture center and not image pixel coordinates so the endpoints need not be integer.
#     - 2D spectra to use. Can use the SSEM or SEXM. The SSEM doesnt have the sky substracted, and the background substraction can be done with IRAF and apall. SEXM has the background substracted by the VIMOS pipeline so background can be set to none
#
# To check what values can the website: https://vimos.manuelpm.me/

# %%
sourcename = 'cx253ssem'
center = 80
low = -1
high = 5
b_low = [0,0]
b_up = [85-center,95-center]
databasegeneral = 'database/apcx253'
filename = 'database/ap'+sourcename
fitsfilename = 'VI_SSEM_577980_2011-07-29T03:55:24.527_G475_MR_302273_Q3_hi.fits'

# %% [markdown]
# ## Exposure time
#
# First we multiply the 2D spectra times the exposure time

# %%
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)

# %% [markdown]
# ##  Define apertures and background sample in the database
#
# We need to change the database of the aperture to define the center, lower and upper limit. Also to define the parameters of the background region to do the background substraction. This is the only way I have found to do it automatically. After this define the parameters in the .par file

# %%
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# # Tue 01:28:30 14-Mar-2017
# begin	aperture cx25sky 1 1250. 119
# 	image	cx253ssem
# 	aperture	1
# 	beam	1
# 	center	1250. 80
# 	low	-1249. -1
# 	high	1250. 5
# 	background
# 		xmin 0
# 		xmax 15
# 		function chebyshev
# 		order 1
# 		sample 0:0,5:15
# 		naverage -3
# 		niterate 0
# 		low_reject 3.
# 		high_reject 3.
# 		grow 0.
# 	axis	2
# 	curve	5
# 		2.
# 		1.
# 		1.
# 		2500.
# 		0.

# %% [markdown]
# ## Calling Apall
#
# Now we define the parameters of apall, save it to the .par file and call the apall function.

# %%
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %% [markdown]
# ## Plotting with Bokeh
#
# Plot the text file after doing dispcor and exporting the spectra to a text file using the iraf routine wspectext.

# %%
#Plotting
##For srfm[0].header["CTYPE1"] = 'LINEAR'
#Other way
#srfm = fits.open(sourcename+'.ms.fits')
#secondstar = srfm[0].data#[0][0]##[0][0] if using clean
#secondstar = srfm[0].data[0][0]
#xn = srfm[0].header["NAXIS1"]
#refx = srfm[0].header["CRVAL1"]
#step = srfm[0].header['CD1_1']
#cr = srfm[0].header['CRPIX1']
#
#xlist = [ refx + step*(i - cr) for i in np.arange(1, len(secondstar)+1) ]
#Create ColumnDataSource
#x = np.array(xlist)
#y = np.array(secondstar)

#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# cx253ssem.ms.fits: Resampling using current coordinate system
# cx253ssem.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd29982b-f307-4ba4-b167-5aafc08ec07a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bd29982b-f307-4ba4-b167-5aafc08ec07a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd29982b-f307-4ba4-b167-5aafc08ec07a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd29982b-f307-4ba4-b167-5aafc08ec07a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4a3c3210-7f7f-4e4b-b5e1-4e48d84a4cf1":{"roots":{"references":[{"attributes":{},"id":"64e79e2c-bdd2-46f4-bce1-ab144f0078a4","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee1212b8-1562-43af-9fb2-884dc5bcf573","type":"Line"},{"attributes":{"callback":null},"id":"6468379b-1021-4484-904f-74dc86eff0d7","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3501.3,3503.9,3506.5,3509.1,3511.7,3514.3,3516.9,3519.5,3522.1,3524.7,3527.3,3529.9,3532.5,3535.1,3537.7,3540.3,3542.9,3545.5,3548.1,3550.7,3553.3,3555.9,3558.5,3561.1,3563.7,3566.3,3568.9,3571.5,3574.1,3576.7,3579.3,3581.9,3584.5,3587.1,3589.7,3592.3,3594.9,3597.5,3600.1,3602.7,3605.3,3607.9,3610.5,3613.1,3615.7,3618.3,3620.9,3623.5,3626.1,3628.7,3631.3,3633.9,3636.5,3639.1,3641.7,3644.3,3646.9,3649.5,3652.1,3654.7,3657.3,3659.9,3662.5,3665.1,3667.7,3670.3,3672.9,3675.5,3678.1,3680.7,3683.3,3685.9,3688.5,3691.1,3693.7,3696.3,3698.9,3701.5,3704.1,3706.7,3709.3,3711.9,3714.5,3717.1,3719.7,3722.3,3724.9,3727.5,3730.1,3732.7,3735.3,3737.9,3740.5,3743.1,3745.7,3748.3,3750.9,3753.5,3756.1,3758.7,3761.3,3763.9,3766.5,3769.1,3771.7,3774.3,3776.9,3779.5,3782.1,3784.7,3787.3,3789.9,3792.5,3795.1,3797.7,3800.3,3802.9,3805.5,3808.1,3810.7,3813.3,3815.9,3818.5,3821.1,3823.7,3826.3,3828.9,3831.5,3834.1,3836.7,3839.3,3841.9,3844.5,3847.1,3849.7,3852.3,3854.9,3857.5,3860.1,3862.7,3865.3,3867.9,3870.5,3873.1,3875.7,3878.3,3880.9,3883.5,3886.1,3888.7,3891.3,3893.9,3896.5,3899.1,3901.7,3904.3,3906.9,3909.5,3912.1,3914.7,3917.3,3919.9,3922.5,3925.1,3927.7,3930.3,3932.9,3935.5,3938.1,3940.7,3943.3,3945.9,3948.5,3951.1,3953.7,3956.3,3958.9,3961.5,3964.1,3966.7,3969.3,3971.9,3974.5,3977.1,3979.7,3982.3,3984.9,3987.5,3990.1,3992.7,3995.3,3997.9,4000.5,4003.1,4005.7,4008.3,4010.9,4013.5,4016.1,4018.7,4021.3,4023.9,4026.5,4029.1,4031.7,4034.3,4036.9,4039.5,4042.1,4044.7,4047.3,4049.9,4052.5,4055.1,4057.7,4060.3,4062.9,4065.5,4068.1,4070.7,4073.3,4075.9,4078.5,4081.1,4083.7,4086.3,4088.9,4091.5,4094.1,4096.7,4099.3,4101.9,4104.5,4107.1,4109.7,4112.3,4114.9,4117.5,4120.1,4122.7,4125.3,4127.9,4130.5,4133.1,4135.7,4138.3,4140.9,4143.5,4146.1,4148.7,4151.3,4153.9,4156.5,4159.1,4161.7,4164.3,4166.9,4169.5,4172.1,4174.7,4177.3,4179.9,4182.5,4185.1,4187.7,4190.3,4192.9,4195.5,4198.1,4200.7,4203.3,4205.9,4208.5,4211.1,4213.7,4216.3,4218.9,4221.5,4224.1,4226.7,4229.3,4231.9,4234.5,4237.1,4239.7,4242.3,4244.9,4247.5,4250.1,4252.7,4255.3,4257.9,4260.5,4263.1,4265.7,4268.3,4270.9,4273.5,4276.1,4278.7,4281.3,4283.9,4286.5,4289.1,4291.7,4294.3,4296.9,4299.5,4302.1,4304.7,4307.3,4309.9,4312.5,4315.1,4317.7,4320.3,4322.9,4325.5,4328.1,4330.7,4333.3,4335.9,4338.5,4341.1,4343.7,4346.3,4348.9,4351.5,4354.1,4356.7,4359.3,4361.9,4364.5,4367.1,4369.7,4372.3,4374.9,4377.5,4380.1,4382.7,4385.3,4387.9,4390.5,4393.1,4395.7,4398.3,4400.9,4403.5,4406.1,4408.7,4411.3,4413.9,4416.5,4419.1,4421.7,4424.3,4426.9,4429.5,4432.1,4434.7,4437.3,4439.9,4442.5,4445.1,4447.7,4450.3,4452.9,4455.5,4458.1,4460.7,4463.3,4465.9,4468.5,4471.1,4473.7,4476.3,4478.9,4481.5,4484.1,4486.7,4489.3,4491.9,4494.5,4497.1,4499.7,4502.3,4504.9,4507.5,4510.1,4512.7,4515.3,4517.9,4520.5,4523.1,4525.7,4528.3,4530.9,4533.5,4536.1,4538.7,4541.3,4543.9,4546.5,4549.1,4551.7,4554.3,4556.9,4559.5,4562.1,4564.7,4567.3,4569.9,4572.5,4575.1,4577.7,4580.3,4582.9,4585.5,4588.1,4590.7,4593.3,4595.9,4598.5,4601.1,4603.7,4606.3,4608.9,4611.5,4614.1,4616.7,4619.3,4621.9,4624.5,4627.1,4629.7,4632.3,4634.9,4637.5,4640.1,4642.7,4645.3,4647.9,4650.5,4653.1,4655.7,4658.3,4660.9,4663.5,4666.1,4668.7,4671.3,4673.9,4676.5,4679.1,4681.7,4684.3,4686.9,4689.5,4692.1,4694.7,4697.3,4699.9,4702.5,4705.1,4707.7,4710.3,4712.9,4715.5,4718.1,4720.7,4723.3,4725.9,4728.5,4731.1,4733.7,4736.3,4738.9,4741.5,4744.1,4746.7,4749.3,4751.9,4754.5,4757.1,4759.7,4762.3,4764.9,4767.5,4770.1,4772.7,4775.3,4777.9,4780.5,4783.1,4785.7,4788.3,4790.9,4793.5,4796.1,4798.7,4801.3,4803.9, ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

# %% [markdown]
# ## Plotting the normalize spectra
#
# We first define the desired range for the initial zoom:

# %%
#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
# Out:
# cx253ssemcont.fits: Resampling using current coordinate system
# cx253ssemcont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9996.1, dw =      2.6, nw = 2499
# GlyphRenderer(id='27cd214a-e661-41e9-bd86-27e97cec57e7', ...)

# %% [markdown]
# ## Overplot lines
#
# If desired we can define several know emission and absoprtion lines to overplot to the normalize spectra

# %%
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7764359c-d032-4902-8bd2-806394a7113a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7764359c-d032-4902-8bd2-806394a7113a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7764359c-d032-4902-8bd2-806394a7113a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7764359c-d032-4902-8bd2-806394a7113a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e6bef7b3-8989-4377-adec-bac7fe378424":{"roots":{"references":[{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"f75679e0-f33a-4ba7-87f2-68c721c46c0e","type":"NormalHead"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"2924ec13-3f3c-4b2d-ac90-8c785fcdaf4b","type":"NormalHead"},{"attributes":{"plot":{"id":"110db8ea-7bf1-41dc-82cb-3e831275628e","subtype":"Figure","type":"Plot"},"text":"Ca II","x":8662,"y":0.8808623},"id":"f144924a-d4ee-40b4-bb8d-e41ff4d0b93e","type":"Label"},{"attributes":{"plot":{"id":"110db8ea-7bf1-41dc-82cb-3e831275628e","subtype":"Figure","type":"Plot"},"text":"Ca II","x":8541,"y":0.8383604},"id":"46f3a5a7-fac9-4e7f-adbf-1dee386c9f2c","type":"Label"},{"attributes":{"end":{"id":"ac021129-cc84-4663-92ca-16672f076a56","type":"NormalHead"},"plot":{"id":"110db8ea-7bf1-41dc-82cb-3e831275628e","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8621},"x_start":{"value":8621},"y_end":{"value":0.9382495},"y_start":{"value":0.8182495}},"id":"27c632d4-9a57-4cc9-a777-b4e229fe056e","type":"Arrow"},{"attributes":{"active_drag":{"id":"379a6382-5ffe-4a83-ba13-9a12567ada40","type":"PanTool"},"active_scroll":{"id":"722adce7-021c-46a0-8522-0862c2738f6a","type":"WheelZoomTool"},"active_tap":"auto","tools":[{"id":"379a6382-5ffe-4a83-ba13-9a12567ada40","type":"PanTool"},{"id":"722adce7-021c-46a0-8522-0862c2738f6a","type":"WheelZoomTool"},{"id":"591b7533-dc98-4057-bb3d-97c20cbad5f5","type":"BoxZoomTool"},{"id":"33b30fb3-99d1-4873-b6bf-490abd360816","type":"SaveTool"},{"id":"8ebca8e9-e216-43ad-bbc2-02e6f17c6a39","type":"ResetTool"},{"id":"c8be58b5-7211-4d1f-a73d-17769d9ae7d2","type":"HelpTool"},{"id":"64920148-0a01-4201-8de6-077e58d4e93e","type":"HoverTool"},{"id":"f47622f6-192f-4cc2-bbd9-b2171f92f93c","type":"ResizeTool"}]},"id":"a4b5a7f8-5e97-46c7-ad1b-7bf1473b8899","type":"Toolbar"},{"attributes":{"plot":{"id":"110db8ea-7bf1-41dc-82cb-3e831275628e","subtype":"Figure","type":"Plot"}},"id":"379a6382-5ffe-4a83-ba13-9a12567ada40","type":"PanTool"},{"attributes":{"below":[{"id":"e3becb65-9f10-4e15-90f1-4d82ce26a19a","type":"LinearAxis"}],"left":[{"id":"fd0c09eb-9760-4056-9cd6-b31a0e9ff379","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"e3becb65-9f10-4e15-90f1-4d82ce26a19a","type":"LinearAxis"},{"id":"29674ecc-f46b-4ceb-8c79-10d4e677556e","type":"Grid"},{"id":"fd0c09eb-9760-4056-9cd6-b31a0e9ff379","type":"LinearAxis"},{"id":"0a434de7-b886-4831-9d86-03c3dfb70a24","type":"Grid"},{"id":"d0f6346d-7fb2-407c-a17b-cc6c933a2196","type":"BoxAnnotation"},{"id":"27cd214a-e661-41e9-bd86-27e97cec57e7","type":"GlyphRenderer"},{"id":"27c632d4-9a57-4cc9-a777-b4e229fe056e","type":"Arrow"},{"id":"502d2318-020f-4938-8f89-8fdc17f55a62","type":"Label"},{"id":"031991a4-8e18-4599-a059-ce5fd5880211","type":"Arrow"},{"id":"f144924a-d4ee-40b4-bb8d-e41ff4d0b93e","type":"Label"},{"id":"b8a6895e-be6b-44d9-bb1b-038dc2872bf3","type":"Arrow"},{"id":"a89ce6fc-cf6c-4cd1-ad37-21354eb8a6e5","type":"Label"},{"id":"de2d39de-515f-46d7-aba8-20188516cb64","type":"Arrow"},{"id":"3d2f0e62-b7a5-48fa-a64b-558084029b9a","type":"Label"},{"id":"36b80aa3-7b4f-4f6e-8e26-203ae98174f3","type":"Arrow"},{"id":"68e13cba-fac5-4d65-bf90-8061656793f8","type":"Label"},{"id":"a46f39e9-3b58-4b87-9448-7c39ad35fb18","type":"Arrow"},{"id":"da3a21f0-88b2-4037-a969-5c8ce27997d2","type":"Label"},{"id":"7c23602a-a5ed-4803-88a6-534bcde71e6d","type":"Arrow"},{"id":"6098ed26-da45-4827-9024-7f3f3ac6732b","type":"Label"},{"id":"bb21e326-427a-4096-9f12-2c6d2a19d3f5","type":"Arrow"},{"id":"56c04b20-a298-4474-9424-cc3c639022a0","type":"Label"},{"id":"88f7239f-2869-468a-9d12-e9071bf5a074","type":"Arrow"},{"id":"05b51914-c2cc-4855-a1c7-2b7b52506d3d","type":"Label"},{"id":"358b3f15-907c-471e-95ea-f97140efaaae","type":"Arrow"},{"id":"46f3a5a7-fac9-4e7f-adbf-1dee386c9f2c","type":"Label"},{"id":"60c66263-2e07-41f4-a4cb-1e1164743904","type":"Arrow"},{"id":"5597c01b-e5ae-48f5-819 ...

# %% [markdown]
# # The spectrum
#
#
# Some filling H$\alpha$
#
# At 9044 and 9382 also present in others. So artefact?

# %% [markdown]
# # Second Source
#
# Look at the index 2499 a little smaller bump at around 66.

# %%
#----------#
#Variables-#
#----------#
sourcename = 'cx253second'
center = 65
low = -6
high = 1
b_low = [55-center,60-center]
b_up = [0,0]
databasegeneral = 'database/apcx253'
filename = 'database/ap'+sourcename
fitsfilename = 'VI_SSEM_577980_2011-07-29T03:55:24.527_G475_MR_302273_Q3_hi.fits'
#----------#
#Exptime---#
#----------#
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)
#----------#
#Database--#
#----------#
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

#----------#
#.par------#
#----------#
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# # Tue 01:28:30 14-Mar-2017
# begin	aperture cx25sky 1 1250. 119
# 	image	cx253second
# 	aperture	1
# 	beam	1
# 	center	1250. 65
# 	low	-1249. -6
# 	high	1210. 1
# 	background
# 		xmin -10
# 		xmax 0
# 		function chebyshev
# 		order 1
# 		sample -10:-5,0:0
# 		naverage -3
# 		niterate 0
# 		low_reject 3.
# 		high_reject 3.
# 		grow 0.
# 	axis	2
# 	curve	5
# 		2.
# 		1.
# 		1.
# 		2500.
# 		0.

# %% [markdown]
# ## Plots

# %%
#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# cx253second.ms.fits: Resampling using current coordinate system
# cx253second.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9894.7, dw =      2.6, nw = 2460
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6f8fbddb-44a7-4411-910c-142dd055e479"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6f8fbddb-44a7-4411-910c-142dd055e479");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f8fbddb-44a7-4411-910c-142dd055e479");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f8fbddb-44a7-4411-910c-142dd055e479' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"327ad87f-db9d-437c-bda0-f01385a2dd13":{"roots":{"references":[{"attributes":{"plot":{"id":"abdd07f5-31f6-40aa-9fb5-42244abbd73a","subtype":"Figure","type":"Plot"}},"id":"39c39a8c-4dd0-426f-b519-8c8f2ec11e15","type":"WheelZoomTool"},{"attributes":{"axis_label":"Y","formatter":{"id":"9d86fead-8249-4e5d-8600-37e06443610a","type":"BasicTickFormatter"},"plot":{"id":"abdd07f5-31f6-40aa-9fb5-42244abbd73a","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0574370-afd6-4c88-8edc-db16b0ef4884","type":"BasicTicker"}},"id":"363e440f-b0cd-48c6-b393-b300855d954f","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3501.3,3503.9,3506.5,3509.1,3511.7,3514.3,3516.9,3519.5,3522.1,3524.7,3527.3,3529.9,3532.5,3535.1,3537.7,3540.3,3542.9,3545.5,3548.1,3550.7,3553.3,3555.9,3558.5,3561.1,3563.7,3566.3,3568.9,3571.5,3574.1,3576.7,3579.3,3581.9,3584.5,3587.1,3589.7,3592.3,3594.9,3597.5,3600.1,3602.7,3605.3,3607.9,3610.5,3613.1,3615.7,3618.3,3620.9,3623.5,3626.1,3628.7,3631.3,3633.9,3636.5,3639.1,3641.7,3644.3,3646.9,3649.5,3652.1,3654.7,3657.3,3659.9,3662.5,3665.1,3667.7,3670.3,3672.9,3675.5,3678.1,3680.7,3683.3,3685.9,3688.5,3691.1,3693.7,3696.3,3698.9,3701.5,3704.1,3706.7,3709.3,3711.9,3714.5,3717.1,3719.7,3722.3,3724.9,3727.5,3730.1,3732.7,3735.3,3737.9,3740.5,3743.1,3745.7,3748.3,3750.9,3753.5,3756.1,3758.7,3761.3,3763.9,3766.5,3769.1,3771.7,3774.3,3776.9,3779.5,3782.1,3784.7,3787.3,3789.9,3792.5,3795.1,3797.7,3800.3,3802.9,3805.5,3808.1,3810.7,3813.3,3815.9,3818.5,3821.1,3823.7,3826.3,3828.9,3831.5,3834.1,3836.7,3839.3,3841.9,3844.5,3847.1,3849.7,3852.3,3854.9,3857.5,3860.1,3862.7,3865.3,3867.9,3870.5,3873.1,3875.7,3878.3,3880.9,3883.5,3886.1,3888.7,3891.3,3893.9,3896.5,3899.1,3901.7,3904.3,3906.9,3909.5,3912.1,3914.7,3917.3,3919.9,3922.5,3925.1,3927.7,3930.3,3932.9,3935.5,3938.1,3940.7,3943.3,3945.9,3948.5,3951.1,3953.7,3956.3,3958.9,3961.5,3964.1,3966.7,3969.3,3971.9,3974.5,3977.1,3979.7,3982.3,3984.9,3987.5,3990.1,3992.7,3995.3,3997.9,4000.5,4003.1,4005.7,4008.3,4010.9,4013.5,4016.1,4018.7,4021.3,4023.9,4026.5,4029.1,4031.7,4034.3,4036.9,4039.5,4042.1,4044.7,4047.3,4049.9,4052.5,4055.1,4057.7,4060.3,4062.9,4065.5,4068.1,4070.7,4073.3,4075.9,4078.5,4081.1,4083.7,4086.3,4088.9,4091.5,4094.1,4096.7,4099.3,4101.9,4104.5,4107.1,4109.7,4112.3,4114.9,4117.5,4120.1,4122.7,4125.3,4127.9,4130.5,4133.1,4135.7,4138.3,4140.9,4143.5,4146.1,4148.7,4151.3,4153.9,4156.5,4159.1,4161.7,4164.3,4166.9,4169.5,4172.1,4174.7,4177.3,4179.9,4182.5,4185.1,4187.7,4190.3,4192.9,4195.5,4198.1,4200.7,4203.3,4205.9,4208.5,4211.1,4213.7,4216.3,4218.9,4221.5,4224.1,4226.7,4229.3,4231.9,4234.5,4237.1,4239.7,4242.3,4244.9,4247.5,4250.1,4252.7,4255.3,4257.9,4260.5,4263.1,4265.7,4268.3,4270.9,4273.5,4276.1,4278.7,4281.3,4283.9,4286.5,4289.1,4291.7,4294.3,4296.9,4299.5,4302.1,4304.7,4307.3,4309.9,4312.5,4315.1,4317.7,4320.3,4322.9,4325.5,4328.1,4330.7,4333.3,4335.9,4338.5,4341.1,4343.7,4346.3,4348.9,4351.5,4354.1,4356.7,4359.3,4361.9,4364.5,4367.1,4369.7,4372.3,4374.9,4377.5,4380.1,4382.7,4385.3,4387.9,4390.5,4393.1,4395.7,4398.3,4400.9,4403.5,4406.1,4408.7,4411.3,4413.9,4416.5,4419.1,4421.7,4424.3,4426.9,4429.5,4432.1,4434.7,4437.3,4439.9,4442.5,4445.1,4447.7,4450.3,4452.9,4455.5,4458.1,4460.7,4463.3,4465.9,4468.5,4471.1,4473.7,4476.3,4478.9,4481.5,4484.1,4486.7,4489.3,4491.9,4494.5,4497.1,4499.7,4502.3,4504.9,4507.5,4510.1,4512.7,4515.3,4517.9,4520.5,4523.1,4525.7,4528.3,4530.9,4533.5,4536.1,4538.7,4541.3,4543.9,4546.5,4549.1,4551.7,4554.3,4556.9,4559.5,4562.1,4564.7,4567.3,4569.9,4572.5,4575.1,4577.7,4580.3,4582.9,4585.5,4588.1,4590.7,4593.3,4595.9,4598.5,4601.1,4603.7,4606.3,4608.9,4611.5,4614.1,4616.7,4619.3,4621.9,4624.5,4627.1,4629.7,4632.3,4634.9,4637.5,4640.1,4642.7,4645.3,4647.9,4650.5,4653.1,4655.7,4658.3,4660.9,4663.5,4666.1,4668.7,4671.3,4673.9,4676.5,4679.1,4681.7,4684.3,4686.9,4689.5,4692.1,4694.7,4697.3,4699.9,4702.5,4705.1,4707.7,4710.3,4712.9,4715.5,4718.1,4720.7,4723.3,4725.9,4728.5,4731.1,4733. ...

# %% [markdown]
# ## Normalize

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)
show(plot)
# Out:
# cx253secondcont.fits: Resampling using current coordinate system
# cx253secondcont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9894.7, dw =      2.6, nw = 2460
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a1b8cf36-4ed6-4370-86e6-89756a734bbe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a1b8cf36-4ed6-4370-86e6-89756a734bbe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1b8cf36-4ed6-4370-86e6-89756a734bbe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1b8cf36-4ed6-4370-86e6-89756a734bbe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"763369b3-7ce9-49d4-93bc-f9499de184c8":{"roots":{"references":[{"attributes":{"plot":null,"text":"Spectra"},"id":"d151ec26-ffa3-4180-8145-d33e86ddba22","type":"Title"},{"attributes":{"below":[{"id":"7847a97d-dc69-4e82-a027-c964ec200aa1","type":"LinearAxis"}],"left":[{"id":"d3ecbfea-3f2d-44a3-abe5-d96b6a70a17a","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"7847a97d-dc69-4e82-a027-c964ec200aa1","type":"LinearAxis"},{"id":"3d7401ae-e102-4de3-ac64-275b0f3aa798","type":"Grid"},{"id":"d3ecbfea-3f2d-44a3-abe5-d96b6a70a17a","type":"LinearAxis"},{"id":"0a9ec7d7-2a69-4956-a9fa-38f96b5f650d","type":"Grid"},{"id":"8059c631-9976-4068-aa20-dfc95e8e616e","type":"BoxAnnotation"},{"id":"443832a2-c7cb-42c1-a42a-345babd88c04","type":"GlyphRenderer"},{"id":"364a52a0-76bd-42a4-853e-f8dc1aebcd1c","type":"Arrow"},{"id":"57d30d5b-0fa8-4649-8098-656c81725f48","type":"Label"},{"id":"1c5a70d6-7256-4bc6-8981-b724a2e5fdec","type":"Arrow"},{"id":"5c166d41-8b67-441b-8739-cbf8ac907fa9","type":"Label"},{"id":"24ceafcf-6713-4bf3-bbda-507528f895a0","type":"Arrow"},{"id":"8486f32d-99f9-42b1-8497-9dfd6450e7aa","type":"Label"},{"id":"c4006fee-c6ef-4a38-bb12-013045c5d3fb","type":"Arrow"},{"id":"e16cb86d-9cc5-43bd-a02d-1b3b2bca63fe","type":"Label"},{"id":"40ac2f2b-6ecd-49bf-adc4-68c6dd1b1a39","type":"Arrow"},{"id":"e03b5dd1-6a4d-40f7-be4b-0b52ae5653fb","type":"Label"},{"id":"2438bcb7-b062-4277-96cb-a24000971598","type":"Arrow"},{"id":"7a731b1b-a429-40c1-b239-4f4c726a06f9","type":"Label"},{"id":"1b9ac359-fe63-4a03-a5f8-371c9bcc8010","type":"Arrow"},{"id":"7f99a23d-2bde-4777-81aa-0d5608851869","type":"Label"},{"id":"02bf0fca-2574-4f8e-97e0-3c11d6e647c0","type":"Arrow"},{"id":"52d69697-3cdf-4db6-b1ad-157915412431","type":"Label"},{"id":"0f166864-257a-4016-99bc-42a99d37cfc2","type":"Arrow"},{"id":"3f7f7b4d-8081-4b24-a923-94eebf7aa700","type":"Label"},{"id":"f8e743bd-004a-4c7e-8665-c3f872090b18","type":"Arrow"},{"id":"5f8dfb96-047a-4641-b7d2-9f728b444690","type":"Label"},{"id":"101bb8a9-dfa4-494c-bf1e-15f567ff7473","type":"Arrow"},{"id":"3a4fb4ff-e2d4-4b39-a7a1-1210c88bf218","type":"Label"},{"id":"a9e270c4-33b2-4fe8-a85a-be0d08235bf3","type":"Arrow"},{"id":"092c8540-9eb7-4ac4-8f0a-cef55d514c78","type":"Label"}],"title":{"id":"d151ec26-ffa3-4180-8145-d33e86ddba22","type":"Title"},"tool_events":{"id":"f5d03e16-fff0-4bf8-a5a9-9bb9c809b238","type":"ToolEvents"},"toolbar":{"id":"01933768-1e86-4220-8e4e-3243ea338f8c","type":"Toolbar"},"x_range":{"id":"24b20d68-0bd6-43a3-ba3b-d207665b45a1","type":"Range1d"},"y_range":{"id":"671e6278-8b6b-4a03-8009-b801d7a10a6c","type":"Range1d"}},"id":"f34b6ecc-4b9e-4c9c-9ef5-41947ac34bde","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"f34b6ecc-4b9e-4c9c-9ef5-41947ac34bde","subtype":"Figure","type":"Plot"},"text":"Fe I","x":8688,"y":0.9754559999999999},"id":"7a731b1b-a429-40c1-b239-4f4c726a06f9","type":"Label"},{"attributes":{"data_source":{"id":"861dbb35-ccd2-4d1c-b51d-88e1ed361804","type":"ColumnDataSource"},"glyph":{"id":"c64a5a94-35ca-4579-ba05-9aa0c12d9e2e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"880aa3cd-9259-4774-8f06-149ffc6f472d","type":"Line"},"selection_glyph":null},"id":"443832a2-c7cb-42c1-a42a-345babd88c04","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f34b6ecc-4b9e-4c9c-9ef5-41947ac34bde","subtype":"Figure","type":"Plot"},"text":"Fe I","x":8621,"y":0.9078241},"id":"8486f32d-99f9-42b1-8497-9dfd6450e7aa","type":"Label"},{"attributes":{"plot":{"id":"f34b6ecc-4b9e-4c9c-9ef5-41947ac34bde","subtype":"Figure","type":"Plot"},"text":"Ca II","x":8662,"y":0.900519},"id":"57d30d5b-0fa8-4649-8098-656c81725f48","type":"Label"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"e50f0d6d-828d-44f4-908a-5e5e2797abac","type":"NormalHead"},{"attributes":{"callback":null,"plot":{"id":"f34b6ecc-4b9e-4c9c-9ef5-41947ac34bde","subtype":"Figure","type":"Plot"},"tooltips":[["(x,y)","($x{1.11}, $y)"]]},"id":"fd ...

# %% [markdown]
# # References
