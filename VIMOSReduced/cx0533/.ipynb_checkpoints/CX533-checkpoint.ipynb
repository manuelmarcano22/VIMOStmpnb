# %% [markdown]
# # CX533
#
# There are three other objects in this region: CX533, CX952 and CX430. It seems to be the brighter one in this folder. This corresponds to the first section from 0 to 50. There are at least two sources. It can be seen at wavelenght greater at 7895 A around 14, and maybe another at around 49.
#
# ![](images/cx533pre.png)
#
# ![](images/cx533sexm.png)
#
#
# - - -
#
#
# ## Information

# %% [markdown]
# # Spectrum extraction
#
# First import the require packages

# %%
from astropy.io import fits
import os
from stsci.tools import capable
capable.OF_GRAPHICS = False
from pyraf import iraf
import numpy as np
from shutil import copyfile
#Bokeh plotting
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span, Label, Arrow, NormalHead
from bokeh.models import HoverTool, tools, ColumnDataSource, CustomJS, Slider, BoxAnnotation
from bokeh.layouts import  column, row
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2f41703b-8697-451e-9a84-fb469de253c0">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Defining the extraction parameters
#
# First we define the parameters to extract the desire spectra:
#     - Name of the extracted spectrum
#     - Center, low and upper limits of the aperture
#     - Background sample. Note that the background coordinates are relative to the aperture center and not image pixel coordinates so the endpoints need not be integer.
#     - 2D spectra to use. Can use the SSEM or SEXM. The SSEM doesnt have the sky substracted, and the background substraction can be done with IRAF and apall. SEXM has the background substracted by the VIMOS pipeline so background can be set to none
#
# To check what values can the website: https://vimos.manuelpm.me/

# %%
sourcename = 'cx533sky'
databasegeneral = 'database/apcx533sexm'
filename = 'database/ap'+sourcename
fitsfilename = 'mos_science_sky_extracted_Q2.fits'

# %%
ape = fits.open(fitsfilename)
##For srfm[0].header["CTYPE1"] = 'LINEAR'
xn = ape[0].header["NAXIS1"]
refx = ape[0].header["CRVAL1"]
step = ape[0].header['CD1_1']
cr = ape[0].header['CRPIX1']
ape = ape[0].data
#
xlist = [ refx + step*(i - cr) for i in np.arange(ape.shape[1] +1) ]
#

#Default is half
y = ape[:,int(ape.shape[1]/2)]
x = list(range(y.shape[0]))
c2 = figure(x_axis_label='index',title='Wavelength',toolbar_location="above",active_scroll='wheel_zoom')
source2 = ColumnDataSource(data=dict(x=x,y=y))
sepaape = 5
sourceall2 = ColumnDataSource(data= dict([ (str(int(xlist[i])), ape[:,i]  ) for i in list(range(0,ape.shape[1],sepaape)) ]))

wavelist =  [ int(xlist[i]) for i in list(range(0,ape.shape[1],sepaape)) ]
sepawave = wavelist[1]- wavelist[0]


c2.line('x','y', source=source2)

callback2 = CustomJS(args=dict(source2 = source2, sourceall2 = sourceall2 ), code="""

        var data2 = source2.data;
        var data22 = sourceall2.data;
        var f = cb_obj.value;
        y = data2['y'];
        y2 = data22[f.toString()];


        for (i = 0; i < y.length; i++) {
            y[i] = y2[i];
        }
        source2.trigger('change');
    """)



slider2 = Slider(title="Wavelength", value=wavelist[int(len(wavelist)/2)], 
                 start=wavelist[0], end=wavelist[-1], step=sepawave,callback=callback2)


hover2 = HoverTool(
        tooltips=[
#            ("index", "$index"),
            ("(x,y)", "($x{1}, $y)"),
        ]
    )
c2.add_tools(hover2)
c2.add_tools(tools.ResizeTool())

layout = column(slider2,c2)
show(layout)

# %% [markdown]
# ## Aperture selection
#
# Select the center the lower and upper limit, as well as the region for the background

# %%
center = 33
low = -2 
high = 2
b_low = [center-center,center-center]
b_up = [38-center,44-center]

# %% [markdown]
# ## Exposure time
#
# First we multiply the 2D spectra times the exposure time

# %%
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)

# %% [markdown]
# ##  Define apertures and background sample in the database
#
# We need to change the database of the aperture to define the center, lower and upper limit. Also to define the parameters of the background region to do the background substraction. This is the only way I have found to do it automatically. After this define the parameters in the .par file

# %%
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# # Tue 01:59:23 14-Mar-2017
# begin	aperture cx533sexm 1 1250. 29.32438
# 	image	cx533sky
# 	aperture	1
# 	beam	1
# 	center	1250. 33
# 	low	-1249. -2
# 	high	1250. 2
# 	background
# 		xmin 0
# 		xmax 11
# 		function chebyshev
# 		order 1
# 		sample 0:0,5:11
# 		naverage -3
# 		niterate 0
# 		low_reject 3.
# 		high_reject 3.
# 		grow 0.
# 	axis	2
# 	curve	5
# 		2.
# 		1.
# 		1.
# 		2500.
# 		0.

# %% [markdown]
# ## Calling Apall
#
# Now we define the parameters of apall, save it to the .par file and call the apall function.

# %%
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %% [markdown]
# ## Plotting with Bokeh
#
# Plot the text file after doing dispcor and exporting the spectra to a text file using the iraf routine wspectext.

# %%
#Plotting
##For srfm[0].header["CTYPE1"] = 'LINEAR'
#Other way
#srfm = fits.open(sourcename+'.ms.fits')
#secondstar = srfm[0].data#[0][0]##[0][0] if using clean
#secondstar = srfm[0].data[0][0]
#xn = srfm[0].header["NAXIS1"]
#refx = srfm[0].header["CRVAL1"]
#step = srfm[0].header['CD1_1']
#cr = srfm[0].header['CRPIX1']
#
#xlist = [ refx + step*(i - cr) for i in np.arange(1, len(secondstar)+1) ]
#Create ColumnDataSource
#x = np.array(xlist)
#y = np.array(secondstar)

#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# cx533sky.ms.fits: Resampling using current coordinate system
# cx533sky.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08d34d53-4073-41a9-aaa6-591435be25e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("08d34d53-4073-41a9-aaa6-591435be25e7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08d34d53-4073-41a9-aaa6-591435be25e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08d34d53-4073-41a9-aaa6-591435be25e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"316f4524-adfa-4bbf-87ad-1e1e1cb23ad0":{"roots":{"references":[{"attributes":{},"id":"bb567440-2e2e-47b6-be8c-4a785aaecd31","type":"BasicTicker"},{"attributes":{"below":[{"id":"8c1cb725-58fb-4af6-b9e7-b01937aba399","type":"LinearAxis"}],"left":[{"id":"95417c96-9067-47b7-89bc-51454079eda5","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"8c1cb725-58fb-4af6-b9e7-b01937aba399","type":"LinearAxis"},{"id":"57434cf2-89a1-4150-9384-55d053025831","type":"Grid"},{"id":"95417c96-9067-47b7-89bc-51454079eda5","type":"LinearAxis"},{"id":"f7fc00b6-538b-4757-aa37-cd6fb994f3d2","type":"Grid"},{"id":"d3dd53ab-fc1c-4f37-ab2c-8482a328c39c","type":"BoxAnnotation"},{"id":"de33a594-a591-40f9-824d-721d66fcac02","type":"GlyphRenderer"}],"title":{"id":"931329a5-d0f1-41b6-9364-f5e72bf4a407","type":"Title"},"tool_events":{"id":"106e2393-b432-415c-9589-791d31dba088","type":"ToolEvents"},"toolbar":{"id":"5896e88e-47e9-4a61-91f6-13e67c6cd262","type":"Toolbar"},"x_range":{"id":"e3faa64f-4b65-47d1-87a8-851ffbb3e148","type":"DataRange1d"},"y_range":{"id":"cf8060a1-6c67-4868-ac63-35687083b438","type":"DataRange1d"}},"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"}},"id":"52fac566-06a4-4f2c-8190-beb2bd74f03f","type":"ResizeTool"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"15fa6c04-7dcf-405e-8279-7473bebfbee6","type":"BasicTickFormatter"},"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b3c1f7b-7db0-4ffb-8cc5-f33417593cfb","type":"BasicTicker"}},"id":"8c1cb725-58fb-4af6-b9e7-b01937aba399","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3642f586-8991-4f7c-b29b-9991427e650c","type":"ColumnDataSource"},"glyph":{"id":"c3f3c891-5010-4de1-8df1-9ce5e1565603","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"879aec94-11c0-40d3-9a39-fb2aa7ff8e97","type":"Line"},"selection_glyph":null},"id":"de33a594-a591-40f9-824d-721d66fcac02","type":"GlyphRenderer"},{"attributes":{},"id":"15fa6c04-7dcf-405e-8279-7473bebfbee6","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c3f3c891-5010-4de1-8df1-9ce5e1565603","type":"Line"},{"attributes":{"overlay":{"id":"d3dd53ab-fc1c-4f37-ab2c-8482a328c39c","type":"BoxAnnotation"},"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"}},"id":"e68d23c2-971d-4aea-8ba7-1066579672c8","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"}},"id":"d9992f79-ad5d-445a-9eed-5a15ac3bcc59","type":"ResetTool"},{"attributes":{},"id":"9b3c1f7b-7db0-4ffb-8cc5-f33417593cfb","type":"BasicTicker"},{"attributes":{},"id":"4a1394c8-e9e1-4d9a-ac36-9eada6723231","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Spectra"},"id":"931329a5-d0f1-41b6-9364-f5e72bf4a407","type":"Title"},{"attributes":{"axis_label":"Y","formatter":{"id":"4a1394c8-e9e1-4d9a-ac36-9eada6723231","type":"BasicTickFormatter"},"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"},"ticker":{"id":"bb567440-2e2e-47b6-be8c-4a785aaecd31","type":"BasicTicker"}},"id":"95417c96-9067-47b7-89bc-51454079eda5","type":"LinearAxis"},{"attributes":{"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"}},"id":"fab798fe-0fca-498b-999a-f914d927302c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"}},"id":"f487a5b8-c54d-42be-bda6-1212799f57cd","type":"SaveTool"},{"attributes":{"callback":null,"plot":{"id":"bb314f51-ea31-47cf-aa53-16a3b5df7ac5","subtype":"Figure","type":"Plot"},"tooltips":[["(x,y)","($x{1.11}, $y)"]]},"id":"42e93e36-1e5a-4b60-96a7-5122ca5acaf6","type":"HoverTool"},{"attributes":{"dimension":1,"plot":{ ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

# %% [markdown]
# ## Plotting the normalize spectra
#
# We first define the desired range for the initial zoom:

# %%
#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
# Out:
# cx533skycont.fits: Resampling using current coordinate system
# cx533skycont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
# GlyphRenderer(id='95dfeaf7-3c14-45d5-9a9f-94f5e596398e', ...)

# %% [markdown]
# ## Overplot lines
#
# If desired we can define several know emission and absoprtion lines to overplot to the normalize spectra

# %%
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="74b313d5-458a-429d-bf37-b89039232d80"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("74b313d5-458a-429d-bf37-b89039232d80");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("74b313d5-458a-429d-bf37-b89039232d80");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '74b313d5-458a-429d-bf37-b89039232d80' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7921dde3-b6a5-41a2-8361-2cb144bcebc3":{"roots":{"references":[{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"193140b7-8f80-4de5-a1a2-63c58d6e42b1","type":"NormalHead"},{"attributes":{"axis_label":"Y","formatter":{"id":"8312ef09-9ba0-43fc-a557-1140d0d1ba8f","type":"BasicTickFormatter"},"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"ticker":{"id":"b16968e6-7728-4457-91a2-2f4c962c2b1d","type":"BasicTicker"}},"id":"2771f9a6-8e9f-4bcf-8883-e3d43b2ef545","type":"LinearAxis"},{"attributes":{"end":{"id":"f786ff46-80e0-49b5-9009-8a910fa314d6","type":"NormalHead"},"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8688},"x_start":{"value":8688},"y_end":{"value":0.9425966},"y_start":{"value":0.8225966}},"id":"4ff39a48-e586-4045-a0ec-5609f5637031","type":"Arrow"},{"attributes":{"end":{"id":"c5de102c-47ba-4560-b2bc-97be3e67701e","type":"NormalHead"},"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8514},"x_start":{"value":8514},"y_end":{"value":0.9596224},"y_start":{"value":0.8396224}},"id":"44b5546b-d650-4ac3-bb4b-83a93628e81b","type":"Arrow"},{"attributes":{},"id":"60577f21-e653-489f-ae07-e31c5e6e1182","type":"BasicTicker"},{"attributes":{"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"text":"Ca II","x":8662,"y":0.779968},"id":"5e3fc750-92d0-4b0d-94a9-7bba8013c25d","type":"Label"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"e6fd958d-9884-42ec-9a67-4fb889eb8773","type":"BasicTickFormatter"},"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"ticker":{"id":"60577f21-e653-489f-ae07-e31c5e6e1182","type":"BasicTicker"}},"id":"bd2e5b5a-fc70-4daf-a710-9b71b63511d5","type":"LinearAxis"},{"attributes":{"end":{"id":"9e40b9f0-b0eb-4636-8ac7-7d2a5e9adb1b","type":"NormalHead"},"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":6563},"x_start":{"value":6563},"y_end":{"value":0.7898999999999999},"y_start":{"value":0.6698999999999999}},"id":"05eec7d3-336e-443b-a2d9-5ece1c680bdd","type":"Arrow"},{"attributes":{"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"text":"O I","x":8446,"y":0.983123},"id":"ff6b18d3-e5c8-4d00-a678-946ab3baa29b","type":"Label"},{"attributes":{"end":{"id":"6917472c-ca41-4211-a9ed-e858c95bb3b8","type":"NormalHead"},"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":6497},"x_start":{"value":6497},"y_end":{"value":0.9278029},"y_start":{"value":0.8078029}},"id":"09bbc665-39ca-4d7f-825a-ff2e22c379f4","type":"Arrow"},{"attributes":{"plot":{"id":"206236b1-ea07-49ab-a569-076a51461bae","subtype":"Figure","type":"Plot"},"text":"H\u03b1","x":6563,"y":0.7898999999999999},"id":"85571ec2-83b2-4c50-99e1-72a067ca1ac8","type":"Label"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"a85c8c8f-25a1-473a-9823-962776926d97","type":"NormalHead"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aa8e76c3-94c0-418f-9a55-0b31e9d16227","type":"BoxAnnotation"},{"attributes":{},"id":"8312ef09-9ba0-43fc-a557-1140d0d1ba8f","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"9e40b9f0-b0eb-4636-8ac7-7d2a5e9adb1b","type":"NormalHead"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"f153075e-1ba3-4730-8e1e-6a7cc431ca26","type":"NormalHead"},{"attributes":{} ...

# %% [markdown]
# # The spectrum
#
#
# H$\alpha$

# %% [markdown]
# # Second Source

# %%
#----------#
#Variables-#
#----------#
sourcename = 
center = 
low = -5
high = 5
b_low = [0,0]
b_up = [40-center,67-center]
databasegeneral = 'database/'
filename = 'database/ap'+sourcename
fitsfilename = 
#----------#
#Exptime---#
#----------#
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)
#----------#
#Database--#
#----------#
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

#----------#
#.par------#
#----------#
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')
# Out:
#   File "<ipython-input-13-794f6322e47d>", line 4
#     sourcename =
#                  ^
# SyntaxError: invalid syntax

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# cat: $filename: No such file or directory

# %% [markdown]
# ## Plots

# %%
#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-14-2a45737483c2> in <module>()
#       3     os.remove(sourcename+'.dispcor.fits')
#       4
# ----> 5 iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
#       6 iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')
#       7
#
# /opt/conda/envs/iraf27/lib/python2.7/site-packages/pyraf/irafimport.pyc in __getattr__(self, attr)
#     166             return self.mmdict[attr]
#     167         except KeyError:
# --> 168             raise AttributeError("Undefined IRAF task `%s'" % (attr,))
#     169
#     170     def __setattr__(self, attr, value):
#
# AttributeError: Undefined IRAF task `dispcor'

# %% [markdown]
# ## Normalize

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)
show(plot)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-15-590bbbf9eb11> in <module>()
#       2 if os.path.exists(sourcename+'cont.fits'):
#       3     os.remove(sourcename+'cont.fits')
# ----> 4 iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
#       5 iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
#       6 iraf.noao.onedspec.continuum.setParam('interactive','no')
#
# /opt/conda/envs/iraf27/lib/python2.7/site-packages/pyraf/iraftask.pyc in __getattr__(self, name)
#    1582         if not self._loaded:
#    1583             raise AttributeError("Package " + self.getName() +
# -> 1584                     " has not been loaded; no tasks are defined")
#    1585         fullname = self._getTaskFullname(name)
#    1586         if fullname:
#
# AttributeError: Package onedspec has not been loaded; no tasks are defined

# %% [markdown]
# # References
