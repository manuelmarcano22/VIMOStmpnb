# %% [markdown]
# # CX967
#
#
# There are two slits CX967 and CX972.
#
#
#
#
# ![](images/both.png)
#
# ![](images/ssem.png)
#
#
#
# From the 2D spectrum and the preimage I think that **CX967** is the first section from **0 to 70**.
#
# - - -
#
#
# ## Information

# %% [markdown]
# # Spectrum extraction
#
# First import the require packages

# %%
from astropy.io import fits
import os
from stsci.tools import capable
capable.OF_GRAPHICS = False
from pyraf import iraf
import numpy as np
from shutil import copyfile
#Bokeh plotting
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span, Label, Arrow, NormalHead
from bokeh.models import HoverTool, tools, ColumnDataSource, CustomJS, Slider, BoxAnnotation
from bokeh.layouts import  column, row
output_notebook()
# Out:
# Created directory /root/VIMOSReduced/cx0967/pyraf for cache
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1efa267e-83b5-4cbd-842f-169d3476025e">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Defining the extraction parameters
#
# First we define the parameters to extract the desire spectra:
#     - Name of the extracted spectrum
#     - Center, low and upper limits of the aperture
#     - Background sample. Note that the background coordinates are relative to the aperture center and not image pixel coordinates so the endpoints need not be integer.
#     - 2D spectra to use. Can use the SSEM or SEXM. The SSEM doesnt have the sky substracted, and the background substraction can be done with IRAF and apall. SEXM has the background substracted by the VIMOS pipeline so background can be set to none
#
# To check what values can the website: https://vimos.manuelpm.me/

# %%
sourcename = 'cx967sky'
databasegeneral = 'database/apcx967sexm'
filename = 'database/ap'+sourcename
fitsfilename = 'mos_science_sky_extracted_Q3.fits'

# %%
ape = fits.open(fitsfilename)
##For srfm[0].header["CTYPE1"] = 'LINEAR'
xn = ape[0].header["NAXIS1"]
refx = ape[0].header["CRVAL1"]
step = ape[0].header['CD1_1']
cr = ape[0].header['CRPIX1']
ape = ape[0].data
#
xlist = [ refx + step*(i - cr) for i in np.arange(ape.shape[1] +1) ]
#

#Default is half
y = ape[:,int(ape.shape[1]/2)]
x = list(range(y.shape[0]))
c2 = figure(x_axis_label='index',title='Wavelength',toolbar_location="above",active_scroll='wheel_zoom')
source2 = ColumnDataSource(data=dict(x=x,y=y))
sepaape = 5
sourceall2 = ColumnDataSource(data= dict([ (str(int(xlist[i])), ape[:,i]  ) for i in list(range(0,ape.shape[1],sepaape)) ]))

wavelist =  [ int(xlist[i]) for i in list(range(0,ape.shape[1],sepaape)) ]
sepawave = wavelist[1]- wavelist[0]


c2.line('x','y', source=source2)

callback2 = CustomJS(args=dict(source2 = source2, sourceall2 = sourceall2 ), code="""

        var data2 = source2.data;
        var data22 = sourceall2.data;
        var f = cb_obj.value;
        y = data2['y'];
        y2 = data22[f.toString()];


        for (i = 0; i < y.length; i++) {
            y[i] = y2[i];
        }
        source2.trigger('change');
    """)



slider2 = Slider(title="Wavelength", value=wavelist[int(len(wavelist)/2)], 
                 start=wavelist[0], end=wavelist[-1], step=sepawave,callback=callback2)


hover2 = HoverTool(
        tooltips=[
#            ("index", "$index"),
            ("(x,y)", "($x{1}, $y)"),
        ]
    )
c2.add_tools(hover2)
c2.add_tools(tools.ResizeTool())

layout = column(slider2,c2)
show(layout)

# %% [markdown]
# ## Aperture selection
#
# Select the center the lower and upper limit, as well as the region for the background

# %%
center = 49
low = -5 
high = 5
b_low = [36-center,40-center]
b_up = [70-center,61-center]

# %% [markdown]
# ## Exposure time
#
# First we multiply the 2D spectra times the exposure time

# %%
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)

# %% [markdown]
# ##  Define apertures and background sample in the database
#
# We need to change the database of the aperture to define the center, lower and upper limit. Also to define the parameters of the background region to do the background substraction. This is the only way I have found to do it automatically. After this define the parameters in the .par file

# %%
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# # Tue 15:56:19 14-Mar-2017
# begin	aperture cx967sexm 1 1250. 49.51036
# 	image	cx967sky
# 	aperture	1
# 	beam	1
# 	center	1250. 49
# 	low	-1249. -5
# 	high	1250. 5
# 	background
# 		xmin -13
# 		xmax 21
# 		function chebyshev
# 		order 1
# 		sample -13:-9,12:21
# 		naverage -3
# 		niterate 0
# 		low_reject 3.
# 		high_reject 3.
# 		grow 0.
# 	axis	2
# 	curve	5
# 		2.
# 		1.
# 		1.
# 		2500.
# 		0.

# %% [markdown]
# ## Calling Apall
#
# Now we define the parameters of apall, save it to the .par file and call the apall function.

# %%
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','average')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %% [markdown]
# ## Plotting with Bokeh
#
# Plot the text file after doing dispcor and exporting the spectra to a text file using the iraf routine wspectext.

# %%
#Plotting
##For srfm[0].header["CTYPE1"] = 'LINEAR'
#Other way
#srfm = fits.open(sourcename+'.ms.fits')
#secondstar = srfm[0].data#[0][0]##[0][0] if using clean
#secondstar = srfm[0].data[0][0]
#xn = srfm[0].header["NAXIS1"]
#refx = srfm[0].header["CRVAL1"]
#step = srfm[0].header['CD1_1']
#cr = srfm[0].header['CRPIX1']
#
#xlist = [ refx + step*(i - cr) for i in np.arange(1, len(secondstar)+1) ]
#Create ColumnDataSource
#x = np.array(xlist)
#y = np.array(secondstar)

#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# cx967sky.ms.fits: Resampling using current coordinate system
# cx967sky.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c332a1e5-84ee-43a0-907e-66e74af0849f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c332a1e5-84ee-43a0-907e-66e74af0849f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c332a1e5-84ee-43a0-907e-66e74af0849f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c332a1e5-84ee-43a0-907e-66e74af0849f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e33d8ea1-9c83-4a76-96da-096426a74317":{"roots":{"references":[{"attributes":{"callback":null},"id":"582994f9-6d1a-4493-9998-f93c4f16e18b","type":"DataRange1d"},{"attributes":{"data_source":{"id":"bb7bf780-ca7b-40b5-bc26-5a8afcbfa27b","type":"ColumnDataSource"},"glyph":{"id":"14c4e073-d8d0-4acb-8447-decdad77f426","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f99afcf4-1f59-45e5-85f3-0d2bc7cc17b0","type":"Line"},"selection_glyph":null},"id":"aa6bee1e-fd35-47e4-8d18-ffc83c53a1eb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"}},"id":"1ddb9684-51b3-4e30-a8eb-349224966244","type":"ResetTool"},{"attributes":{"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"}},"id":"b2f81a65-5a93-4262-85f8-2b8b56a08fc2","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"}},"id":"1a693069-419a-4686-9e95-3bec683ed82a","type":"SaveTool"},{"attributes":{},"id":"d2382664-af30-4731-935f-6189041a3f08","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"},"ticker":{"id":"343e72c2-9ce0-46e0-894a-ef9817c141de","type":"BasicTicker"}},"id":"e9c2dc5f-34f2-42df-aa88-7e087fad68a0","type":"Grid"},{"attributes":{"callback":null},"id":"6ff176c7-60e6-4036-bb52-f0f9ca7b7321","type":"DataRange1d"},{"attributes":{"axis_label":"Y","formatter":{"id":"54684315-4b24-4ba5-8e43-4fe2d1f076b4","type":"BasicTickFormatter"},"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"},"ticker":{"id":"b04b13b7-ba8c-45b7-afc3-47aa502f9d55","type":"BasicTicker"}},"id":"043cfd8d-c8bf-4667-a9de-e2b8beb30294","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Spectra"},"id":"966bd17c-3f7c-4e5c-913f-63aaf40174b8","type":"Title"},{"attributes":{},"id":"343e72c2-9ce0-46e0-894a-ef9817c141de","type":"BasicTicker"},{"attributes":{"below":[{"id":"f855be7f-ea7e-4b7a-a2b2-231fe8b8c87a","type":"LinearAxis"}],"left":[{"id":"043cfd8d-c8bf-4667-a9de-e2b8beb30294","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"f855be7f-ea7e-4b7a-a2b2-231fe8b8c87a","type":"LinearAxis"},{"id":"e9c2dc5f-34f2-42df-aa88-7e087fad68a0","type":"Grid"},{"id":"043cfd8d-c8bf-4667-a9de-e2b8beb30294","type":"LinearAxis"},{"id":"503767d5-7a33-4a72-9b2f-0c2493695274","type":"Grid"},{"id":"37089b64-6b4f-4982-aa77-9bfa8e7d7b3b","type":"BoxAnnotation"},{"id":"aa6bee1e-fd35-47e4-8d18-ffc83c53a1eb","type":"GlyphRenderer"}],"title":{"id":"966bd17c-3f7c-4e5c-913f-63aaf40174b8","type":"Title"},"tool_events":{"id":"ab127b0d-fc35-4ce4-b237-bc41ebb4ea7f","type":"ToolEvents"},"toolbar":{"id":"7cb6d65d-e983-41d3-a09e-e1331de30cf0","type":"Toolbar"},"x_range":{"id":"6ff176c7-60e6-4036-bb52-f0f9ca7b7321","type":"DataRange1d"},"y_range":{"id":"582994f9-6d1a-4493-9998-f93c4f16e18b","type":"DataRange1d"}},"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"}},"id":"2568dade-a119-4bf5-beba-f5f2df24c0b3","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"},"ticker":{"id":"b04b13b7-ba8c-45b7-afc3-47aa502f9d55","type":"BasicTicker"}},"id":"503767d5-7a33-4a72-9b2f-0c2493695274","type":"Grid"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"d2382664-af30-4731-935f-6189041a3f08","type":"BasicTickFormatter"},"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"},"ticker":{"id":"343e72c2-9ce0-46e0-894a-ef9817c141de","type":"BasicTicker"}},"id":"f855be7f-ea7e-4b7a-a2b2-231fe8b8c87a","type":"LinearAxis"},{"attributes":{"plot":{"id":"5633a843-bb03-4835-914a-0bb43fd4be87","subtype":"Figure","type":"Plot"}},"id":"bfd02bc1-04ad-4b0c-814c-ace005565 ...

# %% [markdown]
# ## Normalizing the spectrum
#
# We use the iraf routine continuum. We can define a sample to correctly normalize the desire range of wavelenght

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

# %% [markdown]
# ## Plotting the normalize spectra
#
# We first define the desired range for the initial zoom:

# %%
#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
# Out:
# cx967skycont.fits: Resampling using current coordinate system
# cx967skycont.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
# GlyphRenderer(id='f48d53c6-84ec-44c8-955f-89f0334c86aa', ...)

# %% [markdown]
# ## Overplot lines
#
# If desired we can define several know emission and absoprtion lines to overplot to the normalize spectra

# %%
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,
            line('O I'):8446,line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('O I Triplet(72,74,75)'):7774,line('He I'):7065,line('Fe I'):8621,
            line('P16'):8502,line('P15'):8545,line('P14'):8598,line('P13'):8665,
            line('P12'):8750,line('P11'):8863,line('P10'):9015,line('P9'):9229,
            line('P8'):9546,line('P17'):8467,line('P18'):8438,line('P19'):8413,line('P20'):8392}



for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d2454ab8-2f9f-4169-afad-deb1cd77909d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d2454ab8-2f9f-4169-afad-deb1cd77909d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d2454ab8-2f9f-4169-afad-deb1cd77909d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd2454ab8-2f9f-4169-afad-deb1cd77909d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7f84eb5a-59d4-4ef9-b37a-ce8bcea1ec49":{"roots":{"references":[{"attributes":{"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"}},"id":"0d66d166-f309-4458-8561-ff1723b3957c","type":"SaveTool"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"cf068571-d3cd-4a36-9d89-a00171502665","type":"NormalHead"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"ae1f9dd4-9a3c-4bdb-801d-7cdad0e326c9","type":"NormalHead"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"47714ab9-2533-4799-ba6c-2b5b7925cb98","type":"NormalHead"},{"attributes":{},"id":"e47e3d41-eef7-4570-9aca-89000fc2906e","type":"BasicTickFormatter"},{"attributes":{},"id":"12bc91e2-ae84-4310-a1e2-701c5c27ebbb","type":"BasicTicker"},{"attributes":{"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"text":"(BaII, FeI and CaI)","x":6497,"y":0.8916237},"id":"309244d5-ab6d-48dc-9f8c-9839e99ce7cb","type":"Label"},{"attributes":{"end":{"id":"25574eaa-d5a5-4087-84c3-bbb8a89d896d","type":"NormalHead"},"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8498},"x_start":{"value":8498},"y_end":{"value":0.9147436999999999},"y_start":{"value":0.7947436999999999}},"id":"b91c517b-b70b-4454-8c87-4dc3ba7bd370","type":"Arrow"},{"attributes":{"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"text":"H\u03b1","x":6563,"y":0.6178404},"id":"220b3426-8acd-463a-b084-9eab017a4744","type":"Label"},{"attributes":{"callback":null,"end":8900,"start":8400},"id":"c3f768a6-6a07-4980-b65b-4a4d96bc578b","type":"Range1d"},{"attributes":{"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"text":"P13","x":8665,"y":0.8275557},"id":"8c7afc6b-e7bf-4a73-a2fd-fe5bc6dbac21","type":"Label"},{"attributes":{"end":{"id":"72ae9621-0a5d-4554-869b-ebaee80234c8","type":"NormalHead"},"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":8392},"x_start":{"value":8392},"y_end":{"value":0.9256124},"y_start":{"value":0.8056124}},"id":"3032dbd0-f544-4319-9d72-518eae4a78f5","type":"Arrow"},{"attributes":{"end":{"id":"50de6020-9a1f-4835-878c-7c176bcedac9","type":"NormalHead"},"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":6563},"x_start":{"value":6563},"y_end":{"value":0.6178404},"y_start":{"value":0.49784039999999996}},"id":"14152dfb-b83b-4fb3-bcd0-2eddfa2fa981","type":"Arrow"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"ed56d0ed-f70b-4cbf-9029-fb2e01fb6fcd","type":"NormalHead"},{"attributes":{"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"text":"P19","x":8413,"y":0.9432292},"id":"1465b959-84f2-4d29-9aa6-6aebde58cd0a","type":"Label"},{"attributes":{"end":{"id":"47714ab9-2533-4799-ba6c-2b5b7925cb98","type":"NormalHead"},"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":9015},"x_start":{"value":9015},"y_end":{"value":0.7014149},"y_start":{"value":0.5814149}},"id":"9baddcbd-eab0-4177-8ef0-45597ef139a9","type":"Arrow"},{"attributes":{"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"text":"P9","x":9229,"y":0.6338969999999999},"id":"ad3675ba-7104-48a6-96ef-880881ad6dac","type":"Label"},{"attributes":{"fill_color":{"value":"orange"},"plot":null,"size":10},"id":"838d40e3-808d-4508-9d88-d97ac30ac3d0","type":"NormalHead"},{"attributes":{"end":{"id":"6dbd026a-6fe6-4658-a0fd-7b05d641791f","type":"NormalHead"},"plot":{"id":"dd414efe-827d-462b-8810-2f6a83f75a9a","subtype":"Figure","type":"Plot"},"source":null,"start":null,"x_end":{"value":7774},"x_start":{"value":7774},"y_end":{"value ...

# %% [markdown]
# # The spectrum
#
#
# Hard

# %% [markdown]
# # Second Source

# %%
#----------#
#Variables-#
#----------#
sourcename = 'cx967sexm'
center = 49
low = -3
high = 3
b_low = [0,0]
b_up = [0,0]
databasegeneral = 'database/apcx967'
filename = 'database/ap'+sourcename
fitsfilename = 'mos_science_extracted_Q3.fits'
#----------#
#Exptime---#
#----------#
spectrawithsky = fits.open(fitsfilename)
exptime = spectrawithsky[0].header['EXPTIME']
iraf.stsdas()
iraf.images.imutil()
if os.path.exists(sourcename+'.fits'):
    os.remove(sourcename+'.fits')
    
iraf.images.imutil.imarith(fitsfilename,'*', exptime,sourcename)
#----------#
#Database--#
#----------#
copyfile(databasegeneral,filename)
#Now read and replace center and upper and lower values
with open(filename) as f:
    for lines in f:
        if 'image' in lines:
                imagenameor = lines
                imagename= lines.replace(lines.split()[1],sourcename)
        if 'center' in lines:
                numerocenteror = lines
                numerocenter = lines.replace(lines.split()[2], str(center))
        if 'low' in lines:
                numerolowor = lines
                numerolow = lines.replace(lines.split()[2],str(low))
        if 'high' in lines:
                numerohighor = lines
                numerohigh = lines.replace(lines.split()[2], str(high))
        if 'xmin' in lines:
            bloworiginal  = lines
            blow = lines.replace(lines.split()[1],str(min(b_low)))
        if 'xmax' in lines:
            buporiginal  = lines
            bup = lines.replace(lines.split()[1],str(max(b_up)))
        if 'sample' in lines:
            sampleor = lines
            sampleb = '\t\tsample '+str(min(b_low))+':'+str(max(b_low))+','+str(min(b_up))+':'+str(max(b_up))+'\n'
            break

with open(filename) as f:
    filedata = f.read()

filedata = filedata.replace(imagenameor,imagename)
filedata = filedata.replace(numerocenteror,numerocenter)
filedata = filedata.replace(numerolowor,numerolow)
filedata = filedata.replace(numerohighor,numerohigh)
filedata = filedata.replace(bloworiginal,blow)
filedata = filedata.replace(buporiginal,bup)
filedata = filedata.replace(sampleor,sampleb)

                                
with open(filename,'w') as f:
    f.write(filedata)

#----------#
#.par------#
#----------#
if os.path.exists(sourcename+'.ms.fits'):
    os.remove(sourcename+'.ms.fits')
#Call them 
iraf.noao.twodspec()
iraf.noao.twodspec.apextract()
iraf.noao.twodspec.apextract.setParam('dispaxis','1')
#http://vivaldi.ll.iac.es/sieinvens/siepedia/pmwiki.php?n=HOWTOs.PythonianIRAF
iraf.noao.apextract.apall.setParam('input',sourcename+'.fits')
iraf.noao.apextract.apall.setParam('output',sourcename+'.ms.fits')
iraf.noao.twodspec.apextract.apall.setParam('recenter','no')
iraf.noao.twodspec.apextract.apall.setParam('resize','no')
iraf.noao.twodspec.apextract.apall.setParam('edit','no')
iraf.noao.twodspec.apextract.apall.setParam('trace','no')
iraf.noao.twodspec.apextract.apall.setParam('interactive','no')
iraf.noao.twodspec.apextract.apall.setParam('apertures','1')
iraf.noao.twodspec.apextract.apall.setParam('find','no')
iraf.noao.twodspec.apextract.apall.setParam('clean','yes')
iraf.noao.twodspec.apextract.apall.setParam('background','none')
iraf.noao.twodspec.apextract.apall.setParam('b_sample','-10,0:0,0')
iraf.noao.apextract.apall.saveParList(filename='uparm/'+sourcename+'.par')
iraf.noao.twodspec.apextract.apall(ParList='uparm/'+sourcename+'.par')

# %%
# %%bash -s "$filename"
# cat $1
# Out:
# # Tue 15:56:19 14-Mar-2017
# begin	aperture cx967sexm 1 1250. 49.51036
# 	image	cx967sexm
# 	aperture	1
# 	beam	1
# 	center	1250. 49
# 	low	-1249. -3
# 	high	1250. 3
# 	background
# 		xmin 0
# 		xmax 0
# 		function chebyshev
# 		order 1
# 		sample 0:0,0:0
# 		naverage -3
# 		niterate 0
# 		low_reject 3.
# 		high_reject 3.
# 		grow 0.
# 	axis	2
# 	curve	5
# 		2.
# 		1.
# 		1.
# 		2500.
# 		0.

# %% [markdown]
# ## Plots

# %%
#Not sure if I need to do this
if os.path.exists(sourcename+'.dispcor.fits'):
    os.remove(sourcename+'.dispcor.fits')

iraf.dispcor(sourcename+'.ms.fits',sourcename+'.dispcor.fits')
iraf.wspectext(sourcename+'.dispcor.fits[*,1,1]',sourcename+'.txt',header='no')

x=[]
y=[]
with open(sourcename+'.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))


source = ColumnDataSource(data=dict(x=x,y=y))
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra",
              active_scroll='wheel_zoom',plot_width=900, plot_height=700)
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
show(plot)
# Out:
# cx967sexm.ms.fits: Resampling using current coordinate system
# cx967sexm.dispcor.fits: ap = 1, w1 =   3501.3, w2 =   9998.7, dw =      2.6, nw = 2500
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d37b8d13-a28c-4c06-96e8-5af59c1f09f2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d37b8d13-a28c-4c06-96e8-5af59c1f09f2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d37b8d13-a28c-4c06-96e8-5af59c1f09f2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd37b8d13-a28c-4c06-96e8-5af59c1f09f2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7b14a3cd-1584-43c7-8648-71b2195e3657":{"roots":{"references":[{"attributes":{"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"},"ticker":{"id":"060e475e-a03b-432e-8718-d947652ca0b7","type":"BasicTicker"}},"id":"f433f88d-4b82-46b1-ba14-1cfa8ad23eea","type":"Grid"},{"attributes":{"axis_label":"Angstrom","formatter":{"id":"8a17a058-de9f-42e6-9067-decc00ea296f","type":"BasicTickFormatter"},"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"},"ticker":{"id":"060e475e-a03b-432e-8718-d947652ca0b7","type":"BasicTicker"}},"id":"a28705df-75cb-4014-91c0-3a717d6bc3e7","type":"LinearAxis"},{"attributes":{"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"}},"id":"2dc3130e-8c3d-493d-8b3a-d8766c353591","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94c14277-c377-4164-b84e-1831c98c4a3f","type":"Line"},{"attributes":{},"id":"3b3941c9-a39d-491c-bd86-089609fd2662","type":"BasicTicker"},{"attributes":{"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"}},"id":"a8a691a7-e0ff-449a-92a9-70ef62a6ac31","type":"PanTool"},{"attributes":{"below":[{"id":"a28705df-75cb-4014-91c0-3a717d6bc3e7","type":"LinearAxis"}],"left":[{"id":"4bf13685-7033-4089-9d77-9ed08d52b0bf","type":"LinearAxis"}],"plot_height":700,"plot_width":900,"renderers":[{"id":"a28705df-75cb-4014-91c0-3a717d6bc3e7","type":"LinearAxis"},{"id":"f433f88d-4b82-46b1-ba14-1cfa8ad23eea","type":"Grid"},{"id":"4bf13685-7033-4089-9d77-9ed08d52b0bf","type":"LinearAxis"},{"id":"4fc51475-eddd-4614-8a73-daeeb0e011a4","type":"Grid"},{"id":"770b1828-306e-42db-9463-776520e70844","type":"BoxAnnotation"},{"id":"604062ca-b7a8-481a-bf28-f79818ebbe02","type":"GlyphRenderer"}],"title":{"id":"25dcdfdf-dd5d-4e23-a21c-7e1b8c267b24","type":"Title"},"tool_events":{"id":"7fb31319-effe-4d6c-bcd1-a023f49fad07","type":"ToolEvents"},"toolbar":{"id":"470e7e16-28ad-46a7-9c3c-ba1f0b9badab","type":"Toolbar"},"x_range":{"id":"07874a0a-106b-4733-b414-f1fbab3f0f68","type":"DataRange1d"},"y_range":{"id":"467cf39e-e376-4f8e-9149-9c01a509d4f0","type":"DataRange1d"}},"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"5c61fd89-fd0d-4374-9ae3-24adab407027","type":"ColumnDataSource"},"glyph":{"id":"94c14277-c377-4164-b84e-1831c98c4a3f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"76167577-55d2-4340-abd5-9205cff84dbe","type":"Line"},"selection_glyph":null},"id":"604062ca-b7a8-481a-bf28-f79818ebbe02","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"07874a0a-106b-4733-b414-f1fbab3f0f68","type":"DataRange1d"},{"attributes":{},"id":"060e475e-a03b-432e-8718-d947652ca0b7","type":"BasicTicker"},{"attributes":{"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"}},"id":"ee5445af-edbf-487a-ab2a-0ec6e9300d34","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b3941c9-a39d-491c-bd86-089609fd2662","type":"BasicTicker"}},"id":"4fc51475-eddd-4614-8a73-daeeb0e011a4","type":"Grid"},{"attributes":{"axis_label":"Y","formatter":{"id":"36f52e98-f4f7-4b09-8556-016c7c2c12ff","type":"BasicTickFormatter"},"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b3941c9-a39d-491c-bd86-089609fd2662","type":"BasicTicker"}},"id":"4bf13685-7033-4089-9d77-9ed08d52b0bf","type":"LinearAxis"},{"attributes":{"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"}},"id":"c5dd206f-be56-4bdd-b4ee-0a91cf79ec04","type":"ResizeTool"},{"attributes":{"plot":{"id":"98a7ca8b-fc72-4ff1-98ab-39bac5e0549a","subtype":"Figure","type":"Plot"}},"id":"f31fff11-a9f1-44f4-bde7-7dd6410f19ad","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1} ...

# %% [markdown]
# ## Normalize

# %%
sample = '5000:9000'
if os.path.exists(sourcename+'cont.fits'):
    os.remove(sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
iraf.noao.onedspec.continuum.setParam('interactive','no')
iraf.noao.onedspec.continuum.setParam('sample',sample)
iraf.noao.onedspec.continuum.saveParList(filename='uparm/cont'+sourcename+'.par')
iraf.noao.onedspec.continuum(ParList='uparm/cont'+sourcename+'.par')

#Plotting
xr = (8400,8900)
yr = (0.7,1.1)

#Not sure if I need to do this
if os.path.exists(sourcename+'cont.dispcor.fits'):
    os.remove(sourcename+'cont.dispcor.fits')

iraf.dispcor(sourcename+'cont.fits',sourcename+'cont.dispcor.fits')
iraf.wspectext(sourcename+'cont.dispcor.fits[*,1,1]',sourcename+'cont.txt',header='no')

x=[]
y=[]
with open(sourcename+'cont.txt') as f:
    for lines in f:
        x.append(float(lines.split()[0]))
        y.append(float(lines.split()[1]))

x = np.array(x)
#
hover = HoverTool(
        tooltips=[
            #("index", "$index"),
            ("(x,y)", "($x{1.11}, $y)"),
        ]
    )

source = ColumnDataSource(data=dict(x=x,y=y))

plot = figure(x_axis_label='Angstrom', y_axis_label='Y',title="Spectra", x_range=xr, y_range=yr
              ,active_drag='pan', active_scroll='wheel_zoom',
              plot_width=900, plot_height=700
             )
plot.add_tools(hover)
plot.add_tools(tools.ResizeTool())
plot.line('x','y',source=source)
##Emission Lines
class line(object):
    def __init__(self,name):
        self.name = name


diclines = {line('Ca II'):8498,line('Ca II'):8662,line('Ca II'):8541,line('Fe I'):8621,line('Fe I'):8688,
            line('O I'):8446,line('Fe I'):8514,line('Fe I'):8468,
           line('H'+u"\u03B1"):6563,line("(BaII, FeI and CaI)"):6497,
            line('Ca I'):6162,line('Mg I'):8807}

for name, xloc in diclines.iteritems():
    yloc = y[np.where(abs(xloc - x) < 2)[0][0]]
    span = Arrow(end=NormalHead(fill_color='orange', size=10),
             x_start=xloc, y_start = yloc - .15, x_end = xloc, y_end= yloc-.03
            )
    plot.add_layout(span)
    my_label = Label(x=xloc, y=yloc-.03, text=name.name)
    plot.add_layout(my_label)
show(plot)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-15-590bbbf9eb11> in <module>()
#       2 if os.path.exists(sourcename+'cont.fits'):
#       3     os.remove(sourcename+'cont.fits')
# ----> 4 iraf.noao.onedspec.continuum.setParam('input',sourcename+'.ms.fits')
#       5 iraf.noao.onedspec.continuum.setParam('output',sourcename+'cont.fits')
#       6 iraf.noao.onedspec.continuum.setParam('interactive','no')
#
# /opt/conda/envs/iraf27/lib/python2.7/site-packages/pyraf/iraftask.pyc in __getattr__(self, name)
#    1582         if not self._loaded:
#    1583             raise AttributeError("Package " + self.getName() +
# -> 1584                     " has not been loaded; no tasks are defined")
#    1585         fullname = self._getTaskFullname(name)
#    1586         if fullname:
#
# AttributeError: Package onedspec has not been loaded; no tasks are defined

# %% [markdown]
# # References
